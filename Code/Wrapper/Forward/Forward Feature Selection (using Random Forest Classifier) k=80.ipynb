# %% [markdown]
# referensi https://www.analyticsvidhya.com/blog/2021/04/forward-feature-selection-and-its-implementation/

# %%
#instal library mlxtend
# %pip install mlxtend

# %%
#libraries buat seleksi fitur
import pandas as pd
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

#libraries buat klasifikasi
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm

# %%
#import dataset
df = pd.read_csv('nirsMangga.csv')

# separate dataset into train and test
x_train, x_test, y_train, y_test = train_test_split(
    df.drop(labels=['No', 'Mango Cultivars', 'Vit C (mg/100g)', 'TA (mg/100g)', 'SSC (oBrix)', 'label'], axis=1),
    df['label'],
    test_size=0.3,
    random_state=0)

x_train.head()
# Out:
#         999.9    1000.3    1000.7    1001.1    1001.4    1001.8    1002.2  \
# 16   0.471459  0.471074  0.470934  0.470379  0.470260  0.469880  0.469497
# 51   0.433239  0.432622  0.432626  0.432379  0.431620  0.430710  0.430836
# 183  0.545045  0.544204  0.543792  0.543596  0.543338  0.542534  0.541493
# 145  0.545846  0.544815  0.544524  0.544631  0.544169  0.543143  0.542535
# 40   0.381048  0.380483  0.380541  0.380151  0.379599  0.379189  0.379009
#
#        1002.6      1003    1003.4  ...    2478.7    2481.1    2483.5  \
# 16   0.469435  0.469454  0.468998  ...  1.413537  1.415740  1.417568
# 51   0.430847  0.430188  0.429470  ...  1.601232  1.602877  1.604524
# 183  0.541139  0.541308  0.540831  ...  1.524657  1.525973  1.527454
# 145  0.542080  0.541842  0.541258  ...  1.421962  1.422955  1.423717
# 40   0.378722  0.378309  0.377719  ...  1.571125  1.572674  1.574303
#
#        2485.8    2488.2    2490.6      2493    2495.4    2497.8    2500.2
# 16   1.419698  1.421711  1.423070  1.424394  1.426121  1.427552  1.428625
# 51   1.605982  1.606778  1.607837  1.608756  1.609967  1.610900  1.611099
# 183  1.529518  1.530097  1.530315  1.530254  1.531191  1.532366  1.533183
# 145  1.424639  1.425080  1.425797  1.426503  1.427164  1.427838  1.428271
# 40   1.576075  1.577273  1.577980  1.578561  1.579334  1.580042  1.581424
#
# [5 rows x 1557 columns]

# %% [markdown]
# # Seleksi Fitur Forward Selection dengan Random Forest Classifier

# %%
# calling the linear regression model
lreg = RandomForestClassifier(n_estimators=100)
sfs1 = sfs(lreg, k_features=80, forward=True, verbose=2, scoring='accuracy', n_jobs=-1)

# %%
# %%time

sfs1 = sfs1.fit(x_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   37.4s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1557 out of 1557 | elapsed:  1.6min finished
#
# [2022-06-03 16:19:44] Features: 1/80 -- score: 0.7846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.1s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   51.0s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1556 out of 1556 | elapsed:  1.5min finished
#
# [2022-06-03 16:21:14] Features: 2/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   51.3s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1555 out of 1555 | elapsed:  1.5min finished
#
# [2022-06-03 16:22:43] Features: 3/80 -- score: 0.9076923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   13.8s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.6s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   51.7s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1554 out of 1554 | elapsed:  1.5min finished
#
# [2022-06-03 16:24:14] Features: 4/80 -- score: 0.9307692307692308[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14

# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1492 out of 1492 | elapsed:  1.5min finished
#
# [2022-06-03 18:00:38] Features: 66/80 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.6s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1491 out of 1491 | elapsed:  1.5min finished
#
# [2022-06-03 18:02:08] Features: 67/80 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1490 out of 1490 | elapsed:  1.5min finished
#
# [2022-06-03 18:03:40] Features: 68/80 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.3s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   52.4s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1489 out of 1489 | elapsed:  1.5min finished
#
# [2022-06-03 18:05:10] Features: 69/80 -- score: 0.923076923076923[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.1s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1488 out of 1488 | elapsed:  1.5min finished
#
# [2022-06-03 18:06:41] Features: 70/80 -- score: 0.923076923076923[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.3s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1487 out of 1487 | elapsed:  1.5min finished
#
# [2022-06-03 18:08:11] Features: 71/80 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   54.0s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1486 out of 1486 | elapsed:  1.5min finished
#
# [2022-06-03 18:09:43] Features: 72/80 -- score: 0.923076923076923[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1485 out of 1485 | elapsed:  1.5min finished
#
# [2022-06-03 18:11:12] Features: 73/80 -- score: 0.9153846153846155[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.3s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1484 out of 1484 | elapsed:  1.5min finished
#
# [2022-06-03 18:12:43] Features: 74/80 -- score: 0.9153846153846155[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   54.0s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1483 out of 1483 | elapsed:  1.5min finished
#
# [2022-06-03 18:14:14] Features: 75/80 -- score: 0.9153846153846155[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.4s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1482 out of 1482 | elapsed:  1.5min finished
#
# [2022-06-03 18:15:45] Features: 76/80 -- score: 0.9153846153846155[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   52.1s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1481 out of 1481 | elapsed:  1.5min finished
#
# [2022-06-03 18:17:12] Features: 77/80 -- score: 0.9153846153846155[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   52.1s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1480 out of 1480 | elapsed:  1.5min finished
#
# [2022-06-03 18:18:40] Features: 78/80 -- score: 0.9153846153846155[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   29.7s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   51.3s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1479 out of 1479 | elapsed:  1.5min finished
#
# [2022-06-03 18:20:08] Features: 79/80 -- score: 0.9153846153846155[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   52.2s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# CPU times: user 31min 19s, sys: 54.9 s, total: 32min 14s
# Wall time: 2h 3min 28s
# [Parallel(n_jobs=-1)]: Done 1478 out of 1478 | elapsed:  1.5min finished
#
# [2022-06-03 18:21:36] Features: 80/80 -- score: 0.923076923076923

# %%
feat_names = list(sfs1.k_feature_names_)
print("Fitur yang diambil adalah: ")
print(feat_names)
len(feat_names)
# Out:
# Fitur yang diambil adalah:
# ['1001.1', '1002.2', '1006.1', '1008.8', '1010.8', '1020', '1023.6', '1024.8', '1035.4', '1039.2', '1039.6', '1042.5', '1042.9', '1053.5', '1054.4', '1055.7', '1059.6', '1063.9', '1068.3', '1075.4', '1088.9', '1089.8', '1100.5', '1104.7', '1118.5', '1120.5', '1127.3', '1133.2', '1135.2', '1151.3', '1154.4', '1157.5', '1160.1', '1161.6', '1164.8', '1171.1', '1171.6', '1179.1', '1179.6', '1181.7', '1219.5', '1257.4', '1267.8', '1273.4', '1277.2', '1283.5', '1292.5', '1302.2', '1317.4', '1331', '1338.5', '1343.4', '1352.5', '1370.4', '1376.2', '1397.7', '1400.7', '1409.1', '1412.2', '1464.8', '1478.2', '1545.1', '1583.8', '1615.4', '1650.4', '1712.5', '1715.9', '1822', '1902.2', '1927.7', '1955.3', '1964.2', '1967.2', '1999', '2197.2', '2206.6', '2361.3', '2407.4', '2471.6', '2485.8']
# 80

# %% [markdown]
# # Klasifikasi Random Forest Classifier

# %%
#buat n-fold cv
#cross validation 10-fold
cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %% [markdown]
# ## Testing Performa Model Random Forest Classifier

# %%
# %%time

#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
n_feat = [80]
n_trees = [100]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RF data Train dengan 80 fitur dan 100 trees:1.0
# Akurasi model RF data Test dengan 80 fitur dan 100 trees:0.93
# Precision model RF data Train dengan 80 fitur dan 100 trees:1.0
# Precision model RF data Test dengan 80 fitur dan 100 trees:0.93
# Recall model RF data Train dengan 80 fitur dan 100 trees:1.0
# Recall model RF data Test dengan 80 fitur dan 100 trees:0.93
#
# CPU times: user 1.46 s, sys: 36.5 ms, total: 1.5 s
# Wall time: 1.5 s

# %%
# %%time

#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
n_feat = [80]
n_trees = [150]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RF data Train dengan 80 fitur dan 150 trees:1.0
# Akurasi model RF data Test dengan 80 fitur dan 150 trees:0.93
# Precision model RF data Train dengan 80 fitur dan 150 trees:1.0
# Precision model RF data Test dengan 80 fitur dan 150 trees:0.93
# Recall model RF data Train dengan 80 fitur dan 150 trees:1.0
# Recall model RF data Test dengan 80 fitur dan 150 trees:0.93
#
# CPU times: user 1.97 s, sys: 41.1 ms, total: 2.01 s
# Wall time: 2.01 s

# %%
# %%time

#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
n_feat = [80]
n_trees = [200]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RF data Train dengan 80 fitur dan 200 trees:1.0
# Akurasi model RF data Test dengan 80 fitur dan 200 trees:0.95
# Precision model RF data Train dengan 80 fitur dan 200 trees:1.0
# Precision model RF data Test dengan 80 fitur dan 200 trees:0.95
# Recall model RF data Train dengan 80 fitur dan 200 trees:1.0
# Recall model RF data Test dengan 80 fitur dan 200 trees:0.95
#
# CPU times: user 2.53 s, sys: 26.5 ms, total: 2.55 s
# Wall time: 2.55 s

# %% [markdown]
# # Klasifikasi Support Vector Machine

# %% [markdown]
# Untuk train dan test set, serta cv-nya ambil dari yang Random Forest Classifier, sama aja

# %% [markdown]
# ## Testing Performa Model Support Vector Machine

# %%
# %%time

#tentukan metode scoring yang digunakan
scoring_svm = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur yang digunakan dalam proses klasifikasi SVM ini
n_feat = [80]

for nfeat in n_feat:     
    #ambil n fitur input hasil seleksi fitur Forward 
    x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
    x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

    #Create a Support Vector Classifier
    clf_svm = svm.SVC()

    #Train the model using the training sets
    clf_svm.fit(x_train_selected, y_train)
    y_pred_svm = clf_svm.predict(x_test_selected)

    #hitung score model dari data train
    scores_svm = cross_validate(clf_svm, x_train_selected, y_train, scoring=scoring_svm, cv=cv, return_train_score=True)

    print("akurasi model SVM data Train dengan " + str(nfeat) + " fitur: " 
          + str(round(scores_svm['train_acc'].mean(), 2)))
    print("akurasi model SVM data Test dengan " + str(nfeat) + " fitur: " 
          + str(round(metrics.accuracy_score(y_test, y_pred_svm), 2)))
    print("Precision model SVM data Train dengan " + str(nfeat) + " fitur:"
          + str(round(scores_svm['train_prec_micro'].mean(), 2)))
    print("Precision model SVM data Test dengan " + str(nfeat) + " fitur:"
          + str(round(metrics.precision_score(y_test, y_pred_svm, average='micro'), 2)))
    print("Recall model SVM data Train dengan " + str(nfeat) + " fitur:"
          + str(round(scores_svm['train_rec_micro'].mean(), 2)))
    print("Recall model SVM data Test dengan " + str(nfeat) + " fitur:"
          + str(round(metrics.recall_score(y_test, y_pred_svm, average='micro'), 2)))
    print(" ")
# Out:
# akurasi model SVM data Train dengan 80 fitur: 0.66
# akurasi model SVM data Test dengan 80 fitur: 0.61
# Precision model SVM data Train dengan 80 fitur:0.66
# Precision model SVM data Test dengan 80 fitur:0.61
# Recall model SVM data Train dengan 80 fitur:0.66
# Recall model SVM data Test dengan 80 fitur:0.61
#
# CPU times: user 102 ms, sys: 7.72 ms, total: 109 ms
# Wall time: 106 ms
