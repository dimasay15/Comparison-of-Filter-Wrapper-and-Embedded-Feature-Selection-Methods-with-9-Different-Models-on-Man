# %% [markdown]
# referensi https://www.analyticsvidhya.com/blog/2021/04/forward-feature-selection-and-its-implementation/

# %%
#instal library mlxtend
# %pip install mlxtend

# %%
#libraries buat seleksi fitur
import pandas as pd
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

#libraries buat klasifikasi
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm

# %%
#import dataset
df = pd.read_csv('nirsMangga.csv')

# separate dataset into train and test
x_train, x_test, y_train, y_test = train_test_split(
    df.drop(labels=['No', 'Mango Cultivars', 'Vit C (mg/100g)', 'TA (mg/100g)', 'SSC (oBrix)', 'label'], axis=1),
    df['label'],
    test_size=0.3,
    random_state=0)

x_train.head()
# Out:
#         999.9    1000.3    1000.7    1001.1    1001.4    1001.8    1002.2  \
# 16   0.471459  0.471074  0.470934  0.470379  0.470260  0.469880  0.469497
# 51   0.433239  0.432622  0.432626  0.432379  0.431620  0.430710  0.430836
# 183  0.545045  0.544204  0.543792  0.543596  0.543338  0.542534  0.541493
# 145  0.545846  0.544815  0.544524  0.544631  0.544169  0.543143  0.542535
# 40   0.381048  0.380483  0.380541  0.380151  0.379599  0.379189  0.379009
#
#        1002.6      1003    1003.4  ...    2478.7    2481.1    2483.5  \
# 16   0.469435  0.469454  0.468998  ...  1.413537  1.415740  1.417568
# 51   0.430847  0.430188  0.429470  ...  1.601232  1.602877  1.604524
# 183  0.541139  0.541308  0.540831  ...  1.524657  1.525973  1.527454
# 145  0.542080  0.541842  0.541258  ...  1.421962  1.422955  1.423717
# 40   0.378722  0.378309  0.377719  ...  1.571125  1.572674  1.574303
#
#        2485.8    2488.2    2490.6      2493    2495.4    2497.8    2500.2
# 16   1.419698  1.421711  1.423070  1.424394  1.426121  1.427552  1.428625
# 51   1.605982  1.606778  1.607837  1.608756  1.609967  1.610900  1.611099
# 183  1.529518  1.530097  1.530315  1.530254  1.531191  1.532366  1.533183
# 145  1.424639  1.425080  1.425797  1.426503  1.427164  1.427838  1.428271
# 40   1.576075  1.577273  1.577980  1.578561  1.579334  1.580042  1.581424
#
# [5 rows x 1557 columns]

# %% [markdown]
# # Seleksi Fitur Forward Selection dengan Random Forest Classifier

# %%
# calling the linear regression model
lreg = RandomForestClassifier(n_estimators=100)
sfs1 = sfs(lreg, k_features=40, forward=True, verbose=2, scoring='accuracy', n_jobs=-1)

# %%
# %%time

sfs1 = sfs1.fit(x_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   37.4s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   58.7s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1557 out of 1557 | elapsed:  1.6min finished
#
# [2022-06-03 00:29:08] Features: 1/40 -- score: 0.7846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   51.6s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1556 out of 1556 | elapsed:  1.5min finished
#
# [2022-06-03 00:30:38] Features: 2/40 -- score: 0.8692307692307694[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.1s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   51.1s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1555 out of 1555 | elapsed:  1.5min finished
#
# [2022-06-03 00:32:08] Features: 3/40 -- score: 0.9[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   51.4s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1554 out of 1554 | elapsed:  1.5min finished
#
# [2022-06-03 00:33:38] Features: 4/40 -- score: 0.923076923076923[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   52.2s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1553 out of 1553 | elapsed:  1.5min finished
#
# [2022-06-03 00:35:08] Features: 5/40 -- score: 0.923076923076923[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   52.3s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 
40 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   54.6s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1522 out of 1522 | elapsed:  1.6min finished
#
# [2022-06-03 01:23:00] Features: 36/40 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1521 out of 1521 | elapsed:  1.6min finished
#
# [2022-06-03 01:24:34] Features: 37/40 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   54.7s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1520 out of 1520 | elapsed:  1.6min finished
#
# [2022-06-03 01:26:08] Features: 38/40 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   54.1s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1519 out of 1519 | elapsed:  1.6min finished
#
# [2022-06-03 01:27:41] Features: 39/40 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   55.1s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# CPU times: user 9min 40s, sys: 20.8 s, total: 10min 1s
# Wall time: 1h 1min 44s
# [Parallel(n_jobs=-1)]: Done 1518 out of 1518 | elapsed:  1.6min finished
#
# [2022-06-03 01:29:15] Features: 40/40 -- score: 0.9230769230769231

# %%
feat_names = list(sfs1.k_feature_names_)
print("Fitur yang diambil adalah: ")
print(feat_names)
len(feat_names)
# Out:
# Fitur yang diambil adalah:
# ['1000.3', '1004.9', '1007.7', '1008.8', '1010.8', '1012.8', '1013.6', '1016', '1018.4', '1027.6', '1036.7', '1039.2', '1040.4', '1042.1', '1072.7', '1085.3', '1096.8', '1108', '1109.9', '1128.7', '1129.7', '1132.2', '1152.3', '1164.8', '1172.1', '1174.2', '1174.8', '1204.8', '1227.6', '1249.5', '1326.9', '1331.7', '1638.9', '1712.5', '1819.5', '1900.8', '1905', '1906.4', '1962.7', '2414.1']
# 40

# %% [markdown]
# # Klasifikasi Random Forest Classifier

# %%
#buat n-fold cv
#cross validation 10-fold
cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %% [markdown]
# ## Testing Performa Model Random Forest Classifier

# %%
# %%time

#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
n_feat = [40]
n_trees = [100]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RF data Train dengan 40 fitur dan 100 trees:1.0
# Akurasi model RF data Test dengan 40 fitur dan 100 trees:0.95
# Precision model RF data Train dengan 40 fitur dan 100 trees:1.0
# Precision model RF data Test dengan 40 fitur dan 100 trees:0.95
# Recall model RF data Train dengan 40 fitur dan 100 trees:1.0
# Recall model RF data Test dengan 40 fitur dan 100 trees:0.95
#
# CPU times: user 1.44 s, sys: 13.8 ms, total: 1.45 s
# Wall time: 1.45 s

# %%
# %%time

#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
n_feat = [40]
n_trees = [150]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RF data Train dengan 40 fitur dan 150 trees:1.0
# Akurasi model RF data Test dengan 40 fitur dan 150 trees:0.95
# Precision model RF data Train dengan 40 fitur dan 150 trees:1.0
# Precision model RF data Test dengan 40 fitur dan 150 trees:0.95
# Recall model RF data Train dengan 40 fitur dan 150 trees:1.0
# Recall model RF data Test dengan 40 fitur dan 150 trees:0.95
#
# CPU times: user 2.1 s, sys: 22.6 ms, total: 2.13 s
# Wall time: 2.12 s

# %%
# %%time

#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
n_feat = [40]
n_trees = [200]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RF data Train dengan 40 fitur dan 200 trees:1.0
# Akurasi model RF data Test dengan 40 fitur dan 200 trees:0.95
# Precision model RF data Train dengan 40 fitur dan 200 trees:1.0
# Precision model RF data Test dengan 40 fitur dan 200 trees:0.95
# Recall model RF data Train dengan 40 fitur dan 200 trees:1.0
# Recall model RF data Test dengan 40 fitur dan 200 trees:0.95
#
# CPU times: user 2.75 s, sys: 50 ms, total: 2.8 s
# Wall time: 2.79 s

# %% [markdown]
# # Klasifikasi Support Vector Machine

# %% [markdown]
# Untuk train dan test set, serta cv-nya ambil dari yang Random Forest Classifier, sama aja

# %% [markdown]
# ## Testing Performa Model Support Vector Machine

# %%
# %%time

#tentukan metode scoring yang digunakan
scoring_svm = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur yang digunakan dalam proses klasifikasi SVM ini
n_feat = [40]

for nfeat in n_feat:     
    #ambil n fitur input hasil seleksi fitur Forward 
    x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
    x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

    #Create a Support Vector Classifier
    clf_svm = svm.SVC()

    #Train the model using the training sets
    clf_svm.fit(x_train_selected, y_train)
    y_pred_svm = clf_svm.predict(x_test_selected)

    #hitung score model dari data train
    scores_svm = cross_validate(clf_svm, x_train_selected, y_train, scoring=scoring_svm, cv=cv, return_train_score=True)

    print("akurasi model SVM data Train dengan " + str(nfeat) + " fitur: " 
          + str(round(scores_svm['train_acc'].mean(), 2)))
    print("akurasi model SVM data Test dengan " + str(nfeat) + " fitur: " 
          + str(round(metrics.accuracy_score(y_test, y_pred_svm), 2)))
    print("Precision model SVM data Train dengan " + str(nfeat) + " fitur:"
          + str(round(scores_svm['train_prec_micro'].mean(), 2)))
    print("Precision model SVM data Test dengan " + str(nfeat) + " fitur:"
          + str(round(metrics.precision_score(y_test, y_pred_svm, average='micro'), 2)))
    print("Recall model SVM data Train dengan " + str(nfeat) + " fitur:"
          + str(round(scores_svm['train_rec_micro'].mean(), 2)))
    print("Recall model SVM data Test dengan " + str(nfeat) + " fitur:"
          + str(round(metrics.recall_score(y_test, y_pred_svm, average='micro'), 2)))
    print(" ")
# Out:
# akurasi model SVM data Train dengan 40 fitur: 0.67
# akurasi model SVM data Test dengan 40 fitur: 0.64
# Precision model SVM data Train dengan 40 fitur:0.67
# Precision model SVM data Test dengan 40 fitur:0.64
# Recall model SVM data Train dengan 40 fitur:0.67
# Recall model SVM data Test dengan 40 fitur:0.64
#
# CPU times: user 124 ms, sys: 10.3 ms, total: 135 ms
# Wall time: 130 ms
