# %% [markdown]
# referensi https://www.analyticsvidhya.com/blog/2021/04/forward-feature-selection-and-its-implementation/

# %%
#instal library mlxtend
# %pip install mlxtend

# %%
#libraries buat seleksi fitur
import pandas as pd
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

#libraries buat klasifikasi
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm

# %%
#import dataset
df = pd.read_csv('nirsMangga.csv')

# separate dataset into train and test
x_train, x_test, y_train, y_test = train_test_split(
    df.drop(labels=['No', 'Mango Cultivars', 'Vit C (mg/100g)', 'TA (mg/100g)', 'SSC (oBrix)', 'label'], axis=1),
    df['label'],
    test_size=0.3,
    random_state=0)

x_train.head()
# Out:
#         999.9    1000.3    1000.7    1001.1    1001.4    1001.8    1002.2  \
# 16   0.471459  0.471074  0.470934  0.470379  0.470260  0.469880  0.469497
# 51   0.433239  0.432622  0.432626  0.432379  0.431620  0.430710  0.430836
# 183  0.545045  0.544204  0.543792  0.543596  0.543338  0.542534  0.541493
# 145  0.545846  0.544815  0.544524  0.544631  0.544169  0.543143  0.542535
# 40   0.381048  0.380483  0.380541  0.380151  0.379599  0.379189  0.379009
#
#        1002.6      1003    1003.4  ...    2478.7    2481.1    2483.5  \
# 16   0.469435  0.469454  0.468998  ...  1.413537  1.415740  1.417568
# 51   0.430847  0.430188  0.429470  ...  1.601232  1.602877  1.604524
# 183  0.541139  0.541308  0.540831  ...  1.524657  1.525973  1.527454
# 145  0.542080  0.541842  0.541258  ...  1.421962  1.422955  1.423717
# 40   0.378722  0.378309  0.377719  ...  1.571125  1.572674  1.574303
#
#        2485.8    2488.2    2490.6      2493    2495.4    2497.8    2500.2
# 16   1.419698  1.421711  1.423070  1.424394  1.426121  1.427552  1.428625
# 51   1.605982  1.606778  1.607837  1.608756  1.609967  1.610900  1.611099
# 183  1.529518  1.530097  1.530315  1.530254  1.531191  1.532366  1.533183
# 145  1.424639  1.425080  1.425797  1.426503  1.427164  1.427838  1.428271
# 40   1.576075  1.577273  1.577980  1.578561  1.579334  1.580042  1.581424
#
# [5 rows x 1557 columns]

# %% [markdown]
# # Seleksi Fitur Forward Selection dengan Random Forest Classifier

# %%
# calling the linear regression model
lreg = RandomForestClassifier(n_estimators=100)
sfs1 = sfs(lreg, k_features=100, forward=True, verbose=2, scoring='accuracy', n_jobs=-1)

# %%
# %%time

sfs1 = sfs1.fit(x_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   20.8s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   37.4s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   58.4s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1557 out of 1557 | elapsed:  1.6min finished
#
# [2022-06-03 21:02:45] Features: 1/100 -- score: 0.7846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   50.7s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1556 out of 1556 | elapsed:  1.5min finished
#
# [2022-06-03 21:04:15] Features: 2/100 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   50.9s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1555 out of 1555 | elapsed:  1.5min finished
#
# [2022-06-03 21:05:43] Features: 3/100 -- score: 0.9076923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1554 out of 1554 | elapsed:  1.5min finished
#
# [2022-06-03 21:07:12] Features: 4/100 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.7s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   51.7s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1553 out of 1553 | elapsed:  1.5min finished
#
# [2022-06-03 21:08:42] Features: 5/100 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   51.4s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1552 out of 1552 | elapsed:  1.5min finished
#
# [2022-06-03 21:10:12] Features: 6/100 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.2s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1551 out of 1551 | elapsed:  1.5min finished
#
# [2022-06-03 21:11:41] Features: 7/100 -- score: 0.9307692307692308[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   51.4s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1550 out of 1550 | elapsed:  1.5min finished
#
# [2022-06-03 21:13:10] Features: 8/100 -- score: 0.9307692307692308[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   51.8s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1549 out of 1549 | elapsed:  1.5min finished
#
# [2022-06-03 21:14:41] Features: 9/100 -- score: 0.9307692307692308[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   52.4s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1548 out of 1548 | elapsed:  1.5min finished
#
# [2022-06-03 21:16:11] Features: 10/100 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   52.8s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1547 out of 1547 | elapsed:  1.5min finished
#
# [2022-06-03 21:17:42] Features: 11/100 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   52.5s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1546 out of 1546 | elapsed:  1.5min finished
#
# [2022-06-03 21:19:13] Features: 12/100 -- score: 0.9307692307692308[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   52.6s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1545 out of 1545 | elapsed:  1.5min finished
#
# [2022-06-03 21:20:44] Features: 13/100 -- score: 0.9307692307692308[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   52.6s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1544 out of 1544 | elapsed:  1.5min finished
#
# [2022-06-03 21:22:15] Features: 14/100 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   30.9s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1543 out of 1543 | elapsed:  1.5min finished
#
# [2022-06-03 21:23:46] Features: 15/100 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.3s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1542 out of 1542 | elapsed:  1.5min finished
#
# [2022-06-03 21:25:18] Features: 16/100 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.4s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1541 out of 1541 | elapsed:  1.5min finished
#
# [2022-06-03 21:26:50] Features: 17/100 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.6s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.3s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1540 out of 1540 | elapsed:  1.5min finished
#
# [2022-06-03 21:28:22] Features: 18/100 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.2s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1539 out of 1539 | elapsed:  1.5min finished
#
# [2022-06-03 21:29:54] Features: 19/100 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.1s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1538 out of 1538 | elapsed:  1.5min finished
#
# [2022-06-03 21:31:27] Features: 20/100 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.5s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1537 out of 1537 | elapsed:  1.5min finished
#
# [2022-06-03 21:32:59] Features: 21/100 -- score: 0.923076923076923[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   52.8s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1536 out of 1536 | elapsed:  1.5min finished
#
# [2022-06-03 21:34:30] Features: 22/100 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.1s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1535 out of 1535 | elapsed:  1.5min finished
#
# [2022-06-03 21:36:02] Features: 23/100 -- score: 0.923076923076923[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.2s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1534 out of 1534 | elapsed:  1.5min finished
#
# [2022-06-03 21:37:34] Features: 24/100 -- score: 0.9153846153846155[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   54.3s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1533 out of 1533 | elapsed:  1.6min finished
#
# [2022-06-03 21:39:07] Features: 25/100 -- score: 0.9153846153846155[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.6s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1532 out of 1532 | elapsed:  1.5min finished
#
# [2022-06-03 21:40:40] Features: 26/100 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.4s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1531 out of 1531 | elapsed:  1.5min finished
#
# [2022-06-03 21:42:12] Features: 27/100 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.8s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1530 out of 1530 | elapsed:  1.5min finished
#
# [2022-06-03 21:43:45] Features: 28/100 -- score: 0.9153846153846155[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.8s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.7s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1529 out of 1529 | elapsed:  1.5min finished
#
# [2022-06-03 21:45:17] Features: 29/100 -- score: 0.9230769230769231[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.4s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.6s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1528 out of 1528 | elapsed:  1.5min finished
#
# [2022-06-03 21:46:49] Features: 30/100 -- score: 0.9153846153846155[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2

# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# CPU times: user 46min 40s, sys: 1min 13s, total: 47min 53s
# Wall time: 2h 29min 53s
# [Parallel(n_jobs=-1)]: Done 1458 out of 1458 | elapsed:  1.4min finished
#
# [2022-06-03 23:31:03] Features: 100/100 -- score: 0.9230769230769231

# %%
feat_names = list(sfs1.k_feature_names_)
print("Fitur yang diambil adalah: ")
print(feat_names)
len(feat_names)
# Out:
# Fitur yang diambil adalah:
# ['1000.3', '1000.7', '1001.8', '1002.2', '1007.3', '1008.1', '1008.8', '1009.2', '1010.8', '1011.6', '1015.6', '1020', '1021.6', '1025.6', '1027.6', '1028', '1031.3', '1031.7', '1033.4', '1034.2', '1035', '1035.4', '1035.9', '1036.3', '1038.8', '1039.6', '1042.1', '1050.1', '1054', '1056.1', '1070.1', '1077.2', '1079.4', '1082.1', '1098.6', '1102.8', '1110.9', '1125.3', '1127.3', '1128.3', '1131.7', '1133.7', '1140.7', '1141.7', '1144.7', '1153.4', '1160.6', '1161.6', '1164.8', '1173.2', '1179.1', '1190.4', '1198.1', '1207', '1207.6', '1219', '1226.5', '1227.6', '1242.9', '1245.3', '1247.1', '1260.4', '1261.1', '1264.7', '1274.1', '1277.8', '1327.6', '1380.6', '1419.9', '1426.9', '1427.7', '1445.2', '1472.3', '1667.4', '1686.9', '1699', '1712.5', '1714.8', '1902.2', '1906.4', '1910.6', '1917.7', '1936.3', '1939.2', '1961.2', '1962.7', '1964.2', '2022.4', '2035.1', '2096', '2099.4', '2137.5', '2151.6', '2167.8', '2217.9', '2274.3', '2280.3', '2335.8', '2455.2', '2488.2']
# 100

# %% [markdown]
# # Klasifikasi Random Forest Classifier

# %%
#buat n-fold cv
#cross validation 10-fold
cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %% [markdown]
# ## Testing Performa Model Random Forest Classifier

# %%
# %%time

#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
n_feat = [100]
n_trees = [100]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RF data Train dengan 100 fitur dan 100 trees:1.0
# Akurasi model RF data Test dengan 100 fitur dan 100 trees:0.91
# Precision model RF data Train dengan 100 fitur dan 100 trees:1.0
# Precision model RF data Test dengan 100 fitur dan 100 trees:0.91
# Recall model RF data Train dengan 100 fitur dan 100 trees:1.0
# Recall model RF data Test dengan 100 fitur dan 100 trees:0.91
#
# CPU times: user 1.38 s, sys: 16.9 ms, total: 1.4 s
# Wall time: 1.4 s

# %%
# %%time

#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
n_feat = [100]
n_trees = [150]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RF data Train dengan 100 fitur dan 150 trees:1.0
# Akurasi model RF data Test dengan 100 fitur dan 150 trees:0.93
# Precision model RF data Train dengan 100 fitur dan 150 trees:1.0
# Precision model RF data Test dengan 100 fitur dan 150 trees:0.93
# Recall model RF data Train dengan 100 fitur dan 150 trees:1.0
# Recall model RF data Test dengan 100 fitur dan 150 trees:0.93
#
# CPU times: user 1.98 s, sys: 33.1 ms, total: 2.01 s
# Wall time: 2 s

# %%
# %%time

#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
n_feat = [100]
n_trees = [200]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RF data Train dengan 100 fitur dan 200 trees:1.0
# Akurasi model RF data Test dengan 100 fitur dan 200 trees:0.93
# Precision model RF data Train dengan 100 fitur dan 200 trees:1.0
# Precision model RF data Test dengan 100 fitur dan 200 trees:0.93
# Recall model RF data Train dengan 100 fitur dan 200 trees:1.0
# Recall model RF data Test dengan 100 fitur dan 200 trees:0.93
#
# CPU times: user 2.61 s, sys: 22.4 ms, total: 2.63 s
# Wall time: 2.62 s

# %% [markdown]
# # Klasifikasi Support Vector Machine

# %% [markdown]
# Untuk train dan test set, serta cv-nya ambil dari yang Random Forest Classifier, sama aja

# %% [markdown]
# ## Testing Performa Model Support Vector Machine

# %%
# %%time

#tentukan metode scoring yang digunakan
scoring_svm = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur yang digunakan dalam proses klasifikasi SVM ini
n_feat = [100]

for nfeat in n_feat:     
    #ambil n fitur input hasil seleksi fitur Forward 
    x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
    x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

    #Create a Support Vector Classifier
    clf_svm = svm.SVC()

    #Train the model using the training sets
    clf_svm.fit(x_train_selected, y_train)
    y_pred_svm = clf_svm.predict(x_test_selected)

    #hitung score model dari data train
    scores_svm = cross_validate(clf_svm, x_train_selected, y_train, scoring=scoring_svm, cv=cv, return_train_score=True)

    print("akurasi model SVM data Train dengan " + str(nfeat) + " fitur: " 
          + str(round(scores_svm['train_acc'].mean(), 2)))
    print("akurasi model SVM data Test dengan " + str(nfeat) + " fitur: " 
          + str(round(metrics.accuracy_score(y_test, y_pred_svm), 2)))
    print("Precision model SVM data Train dengan " + str(nfeat) + " fitur:"
          + str(round(scores_svm['train_prec_micro'].mean(), 2)))
    print("Precision model SVM data Test dengan " + str(nfeat) + " fitur:"
          + str(round(metrics.precision_score(y_test, y_pred_svm, average='micro'), 2)))
    print("Recall model SVM data Train dengan " + str(nfeat) + " fitur:"
          + str(round(scores_svm['train_rec_micro'].mean(), 2)))
    print("Recall model SVM data Test dengan " + str(nfeat) + " fitur:"
          + str(round(metrics.recall_score(y_test, y_pred_svm, average='micro'), 2)))
    print(" ")
# Out:
# akurasi model SVM data Train dengan 100 fitur: 0.56
# akurasi model SVM data Test dengan 100 fitur: 0.54
# Precision model SVM data Train dengan 100 fitur:0.56
# Precision model SVM data Test dengan 100 fitur:0.54
# Recall model SVM data Train dengan 100 fitur:0.56
# Recall model SVM data Test dengan 100 fitur:0.54
#
# CPU times: user 105 ms, sys: 11.5 ms, total: 116 ms
# Wall time: 111 ms
