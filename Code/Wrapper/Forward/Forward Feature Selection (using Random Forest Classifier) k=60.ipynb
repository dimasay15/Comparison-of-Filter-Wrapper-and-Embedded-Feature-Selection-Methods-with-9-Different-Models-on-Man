# %% [markdown]
# referensi https://www.analyticsvidhya.com/blog/2021/04/forward-feature-selection-and-its-implementation/

# %%
#instal library mlxtend
# %pip install mlxtend

# %%
#libraries buat seleksi fitur
import pandas as pd
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

#libraries buat klasifikasi
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm

# %%
#import dataset
df = pd.read_csv('nirsMangga.csv')

# separate dataset into train and test
x_train, x_test, y_train, y_test = train_test_split(
    df.drop(labels=['No', 'Mango Cultivars', 'Vit C (mg/100g)', 'TA (mg/100g)', 'SSC (oBrix)', 'label'], axis=1),
    df['label'],
    test_size=0.3,
    random_state=0)

x_train.head()
# Out:
#         999.9    1000.3    1000.7    1001.1    1001.4    1001.8    1002.2  \
# 16   0.471459  0.471074  0.470934  0.470379  0.470260  0.469880  0.469497
# 51   0.433239  0.432622  0.432626  0.432379  0.431620  0.430710  0.430836
# 183  0.545045  0.544204  0.543792  0.543596  0.543338  0.542534  0.541493
# 145  0.545846  0.544815  0.544524  0.544631  0.544169  0.543143  0.542535
# 40   0.381048  0.380483  0.380541  0.380151  0.379599  0.379189  0.379009
#
#        1002.6      1003    1003.4  ...    2478.7    2481.1    2483.5  \
# 16   0.469435  0.469454  0.468998  ...  1.413537  1.415740  1.417568
# 51   0.430847  0.430188  0.429470  ...  1.601232  1.602877  1.604524
# 183  0.541139  0.541308  0.540831  ...  1.524657  1.525973  1.527454
# 145  0.542080  0.541842  0.541258  ...  1.421962  1.422955  1.423717
# 40   0.378722  0.378309  0.377719  ...  1.571125  1.572674  1.574303
#
#        2485.8    2488.2    2490.6      2493    2495.4    2497.8    2500.2
# 16   1.419698  1.421711  1.423070  1.424394  1.426121  1.427552  1.428625
# 51   1.605982  1.606778  1.607837  1.608756  1.609967  1.610900  1.611099
# 183  1.529518  1.530097  1.530315  1.530254  1.531191  1.532366  1.533183
# 145  1.424639  1.425080  1.425797  1.426503  1.427164  1.427838  1.428271
# 40   1.576075  1.577273  1.577980  1.578561  1.579334  1.580042  1.581424
#
# [5 rows x 1557 columns]

# %% [markdown]
# # Seleksi Fitur Forward Selection dengan Random Forest Classifier

# %%
# calling the linear regression model
lreg = RandomForestClassifier(n_estimators=100)
sfs1 = sfs(lreg, k_features=60, forward=True, verbose=2, scoring='accuracy', n_jobs=-1)

# %%
# %%time

sfs1 = sfs1.fit(x_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   36.0s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   56.5s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1557 out of 1557 | elapsed:  1.6min finished
#
# [2022-06-03 01:39:36] Features: 1/60 -- score: 0.7846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   29.3s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   49.0s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 1556 out of 1556 | elapsed:  1.4min finished
#
# [2022-06-03 01:41:02] Features: 2/60 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   28.7s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   48.1s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 1555 out of 1555 | elapsed:  1.4min finished
#
# [2022-06-03 01:42:26] Features: 3/60 -- score: 0.9[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   48.9s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done

# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1514 out of 1514 | elapsed:  1.6min finished
#
# [2022-06-03 02:44:08] Features: 44/60 -- score: 0.9153846153846154[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.8s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1513 out of 1513 | elapsed:  1.6min finished
#
# [2022-06-03 02:45:42] Features: 45/60 -- score: 0.9153846153846154[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   54.6s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1512 out of 1512 | elapsed:  1.6min finished
#
# [2022-06-03 02:47:16] Features: 46/60 -- score: 0.9153846153846154[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   54.3s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1511 out of 1511 | elapsed:  1.6min finished
#
# [2022-06-03 02:48:49] Features: 47/60 -- score: 0.9153846153846154[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   54.7s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1510 out of 1510 | elapsed:  1.6min finished
#
# [2022-06-03 02:50:23] Features: 48/60 -- score: 0.9153846153846154[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.5s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   32.4s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   55.1s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1509 out of 1509 | elapsed:  1.6min finished
#
# [2022-06-03 02:51:57] Features: 49/60 -- score: 0.9153846153846154[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   32.1s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   54.9s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1508 out of 1508 | elapsed:  1.6min finished
#
# [2022-06-03 02:53:31] Features: 50/60 -- score: 0.9153846153846154[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   54.5s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1507 out of 1507 | elapsed:  1.6min finished
#
# [2022-06-03 02:55:04] Features: 51/60 -- score: 0.9153846153846154[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1506 out of 1506 | elapsed:  1.5min finished
#
# [2022-06-03 02:56:37] Features: 52/60 -- score: 0.9153846153846154[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.5s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1505 out of 1505 | elapsed:  1.5min finished
#
# [2022-06-03 02:58:08] Features: 53/60 -- score: 0.9153846153846154[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.2s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1504 out of 1504 | elapsed:  1.5min finished
#
# [2022-06-03 02:59:39] Features: 54/60 -- score: 0.9153846153846154[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.1s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1503 out of 1503 | elapsed:  1.5min finished
#
# [2022-06-03 03:01:10] Features: 55/60 -- score: 0.9153846153846154[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.3s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.2s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1502 out of 1502 | elapsed:  1.5min finished
#
# [2022-06-03 03:02:41] Features: 56/60 -- score: 0.9153846153846154[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.0s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.2s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   53.7s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 1501 out of 1501 | elapsed:  1.5min finished
#
# [2022-06-03 03:04:13] Features: 57/60 -- score: 0.9153846153846154[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   54.7s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1500 out of 1500 | elapsed:  1.5min finished
#
# [2022-06-03 03:05:46] Features: 58/60 -- score: 0.9153846153846154[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   31.9s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   54.5s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 1499 out of 1499 | elapsed:  1.5min finished
#
# [2022-06-03 03:07:19] Features: 59/60 -- score: 0.9153846153846154[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:   32.0s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   54.0s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:  1.4min
# CPU times: user 18min 27s, sys: 43.5 s, total: 19min 11s
# Wall time: 1h 30min 49s
# [Parallel(n_jobs=-1)]: Done 1498 out of 1498 | elapsed:  1.5min finished
#
# [2022-06-03 03:08:51] Features: 60/60 -- score: 0.9076923076923077

# %%
feat_names = list(sfs1.k_feature_names_)
print("Fitur yang diambil adalah: ")
print(feat_names)
len(feat_names)
# Out:
# Fitur yang diambil adalah:
# ['999.9', '1001.4', '1002.2', '1007.3', '1007.7', '1008.5', '1010.4', '1014', '1014.8', '1016', '1024', '1028.9', '1040', '1040.4', '1047.6', '1055.7', '1068.3', '1074.5', '1076.3', '1085.3', '1087.1', '1094.4', '1097.2', '1105.2', '1143.2', '1150.3', '1159.5', '1161.6', '1162.7', '1164.2', '1166.3', '1183.9', '1185.5', '1204.8', '1211', '1225.9', '1241.1', '1256.2', '1277.2', '1282.9', '1308.1', '1340.6', '1352.5', '1357.5', '1374.7', '1409.1', '1562.8', '1573.3', '1683.6', '1712.5', '1796.8', '1820.7', '1900.8', '1961.2', '1974.7', '2016.1', '2123.5', '2380.8', '2391.8', '2448.3']
# 60

# %% [markdown]
# # Klasifikasi Random Forest Classifier

# %%
#buat n-fold cv
#cross validation 10-fold
cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %% [markdown]
# ## Testing Performa Model Random Forest Classifier

# %%
# %%time

#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
n_feat = [60]
n_trees = [100]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RF data Train dengan 60 fitur dan 100 trees:1.0
# Akurasi model RF data Test dengan 60 fitur dan 100 trees:0.95
# Precision model RF data Train dengan 60 fitur dan 100 trees:1.0
# Precision model RF data Test dengan 60 fitur dan 100 trees:0.95
# Recall model RF data Train dengan 60 fitur dan 100 trees:1.0
# Recall model RF data Test dengan 60 fitur dan 100 trees:0.95
#
# CPU times: user 1.5 s, sys: 17.9 ms, total: 1.52 s
# Wall time: 1.52 s

# %%
# %%time

#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
n_feat = [60]
n_trees = [150]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RF data Train dengan 60 fitur dan 150 trees:1.0
# Akurasi model RF data Test dengan 60 fitur dan 150 trees:0.95
# Precision model RF data Train dengan 60 fitur dan 150 trees:1.0
# Precision model RF data Test dengan 60 fitur dan 150 trees:0.95
# Recall model RF data Train dengan 60 fitur dan 150 trees:1.0
# Recall model RF data Test dengan 60 fitur dan 150 trees:0.95
#
# CPU times: user 2.12 s, sys: 34.6 ms, total: 2.16 s
# Wall time: 2.15 s

# %%
# %%time

#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
n_feat = [60]
n_trees = [200]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RF data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RF data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RF data Train dengan 60 fitur dan 200 trees:1.0
# Akurasi model RF data Test dengan 60 fitur dan 200 trees:0.95
# Precision model RF data Train dengan 60 fitur dan 200 trees:1.0
# Precision model RF data Test dengan 60 fitur dan 200 trees:0.95
# Recall model RF data Train dengan 60 fitur dan 200 trees:1.0
# Recall model RF data Test dengan 60 fitur dan 200 trees:0.95
#
# CPU times: user 2.8 s, sys: 28 ms, total: 2.83 s
# Wall time: 2.82 s

# %% [markdown]
# # Klasifikasi Support Vector Machine

# %% [markdown]
# Untuk train dan test set, serta cv-nya ambil dari yang Random Forest Classifier, sama aja

# %% [markdown]
# ## Testing Performa Model Support Vector Machine

# %%
# %%time

#tentukan metode scoring yang digunakan
scoring_svm = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur yang digunakan dalam proses klasifikasi SVM ini
n_feat = [60]

for nfeat in n_feat:     
    #ambil n fitur input hasil seleksi fitur Forward 
    x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
    x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

    #Create a Support Vector Classifier
    clf_svm = svm.SVC()

    #Train the model using the training sets
    clf_svm.fit(x_train_selected, y_train)
    y_pred_svm = clf_svm.predict(x_test_selected)

    #hitung score model dari data train
    scores_svm = cross_validate(clf_svm, x_train_selected, y_train, scoring=scoring_svm, cv=cv, return_train_score=True)

    print("akurasi model SVM data Train dengan " + str(nfeat) + " fitur: " 
          + str(round(scores_svm['train_acc'].mean(), 2)))
    print("akurasi model SVM data Test dengan " + str(nfeat) + " fitur: " 
          + str(round(metrics.accuracy_score(y_test, y_pred_svm), 2)))
    print("Precision model SVM data Train dengan " + str(nfeat) + " fitur:"
          + str(round(scores_svm['train_prec_micro'].mean(), 2)))
    print("Precision model SVM data Test dengan " + str(nfeat) + " fitur:"
          + str(round(metrics.precision_score(y_test, y_pred_svm, average='micro'), 2)))
    print("Recall model SVM data Train dengan " + str(nfeat) + " fitur:"
          + str(round(scores_svm['train_rec_micro'].mean(), 2)))
    print("Recall model SVM data Test dengan " + str(nfeat) + " fitur:"
          + str(round(metrics.recall_score(y_test, y_pred_svm, average='micro'), 2)))
    print(" ")
# Out:
# akurasi model SVM data Train dengan 60 fitur: 0.68
# akurasi model SVM data Test dengan 60 fitur: 0.61
# Precision model SVM data Train dengan 60 fitur:0.68
# Precision model SVM data Test dengan 60 fitur:0.61
# Recall model SVM data Train dengan 60 fitur:0.68
# Recall model SVM data Test dengan 60 fitur:0.61
#
# CPU times: user 123 ms, sys: 7.69 ms, total: 131 ms
# Wall time: 126 ms
