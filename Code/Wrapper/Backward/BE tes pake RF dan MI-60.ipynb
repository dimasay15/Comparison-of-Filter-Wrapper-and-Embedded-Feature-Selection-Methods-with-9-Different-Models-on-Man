# %% [markdown]
# referensi https://www.analyticsvidhya.com/blog/2021/04/forward-feature-selection-and-its-implementation/

# %%
#instal library mlxtend
# %pip install mlxtend

# %%
#libraries buat seleksi fitur
import pandas as pd
import numpy as np
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import f_classif,SelectKBest 
from sklearn.feature_selection import mutual_info_classif

#libraries buat klasifikasi
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm

# %%
#import dataset
df = pd.read_csv('nirsMangga.csv')

# separate dataset into train and test
x_train, x_test, y_train, y_test = train_test_split(
    df.drop(labels=['No', 'Mango Cultivars', 'Vit C (mg/100g)', 'TA (mg/100g)', 'SSC (oBrix)', 'label'], axis=1),
    df['label'],
    test_size=0.3,
    random_state=0)

x_train.head()
# Out:
#         999.9    1000.3    1000.7    1001.1    1001.4    1001.8    1002.2  \
# 16   0.471459  0.471074  0.470934  0.470379  0.470260  0.469880  0.469497
# 51   0.433239  0.432622  0.432626  0.432379  0.431620  0.430710  0.430836
# 183  0.545045  0.544204  0.543792  0.543596  0.543338  0.542534  0.541493
# 145  0.545846  0.544815  0.544524  0.544631  0.544169  0.543143  0.542535
# 40   0.381048  0.380483  0.380541  0.380151  0.379599  0.379189  0.379009
#
#        1002.6      1003    1003.4  ...    2478.7    2481.1    2483.5  \
# 16   0.469435  0.469454  0.468998  ...  1.413537  1.415740  1.417568
# 51   0.430847  0.430188  0.429470  ...  1.601232  1.602877  1.604524
# 183  0.541139  0.541308  0.540831  ...  1.524657  1.525973  1.527454
# 145  0.542080  0.541842  0.541258  ...  1.421962  1.422955  1.423717
# 40   0.378722  0.378309  0.377719  ...  1.571125  1.572674  1.574303
#
#        2485.8    2488.2    2490.6      2493    2495.4    2497.8    2500.2
# 16   1.419698  1.421711  1.423070  1.424394  1.426121  1.427552  1.428625
# 51   1.605982  1.606778  1.607837  1.608756  1.609967  1.610900  1.611099
# 183  1.529518  1.530097  1.530315  1.530254  1.531191  1.532366  1.533183
# 145  1.424639  1.425080  1.425797  1.426503  1.427164  1.427838  1.428271
# 40   1.576075  1.577273  1.577980  1.578561  1.579334  1.580042  1.581424
#
# [5 rows x 1557 columns]

# %%
# %%time

# determine the mutual information
mutual_info = mutual_info_classif(x_train, y_train)
mutual_info
# Out:
# CPU times: user 4.09 s, sys: 83.2 ms, total: 4.18 s
# Wall time: 4.17 s
# array([0.63194121, 0.63677335, 0.63393088, ..., 0.5091611 , 0.49290951,
#        0.48903907])

# %%
x_train.columns
# Out:
# Index(['999.9', '1000.3', '1000.7', '1001.1', '1001.4', '1001.8', '1002.2',
#        '1002.6', '1003', '1003.4',
#        ...
#        '2478.7', '2481.1', '2483.5', '2485.8', '2488.2', '2490.6', '2493',
#        '2495.4', '2497.8', '2500.2'],
#       dtype='object', length=1557)

# %%
# Create features score, features p_value, and features name
features_mi = pd.DataFrame(mutual_info)
features = pd.DataFrame(x_train.columns)
features_mi = pd.concat([features, features_mi],axis=1)

#reset index, supaya tidak ada nilai nan di dataframe yg dibikin
features_mi.reset_index(drop=True, inplace=True)
features.reset_index(drop=True, inplace=True)

# Assign the column name
features_mi.columns = ["Input_Features", "Mutual Information Value"]

# Print features score
print(features_mi.nlargest(40,columns="Mutual Information Value"))
# Out:
#     Input_Features  Mutual Information Value
# 318         1139.7                  0.709039
# 319         1140.2                  0.703579
# 322         1141.7                  0.702486
# 315         1138.2                  0.700575
# 316         1138.7                  0.699476
# 317         1139.2                  0.696952
# 320         1140.7                  0.695759
# 321         1141.2                  0.689817
# 323         1142.2                  0.689658
# 303         1132.2                  0.687375
# 314         1137.7                  0.686203
# 302         1131.7                  0.681486
# 313         1137.2                  0.678820
# 686         1359.6                  0.678404
# 685         1358.9                  0.676511
# 324         1142.7                  0.673497
# 307         1134.2                  0.671183
# 687         1360.3                  0.667588
# 306         1133.7                  0.667333
# 688           1361                  0.666494
# 301         1131.2                  0.665180
# 304         1132.7                  0.663262
# 556         1272.8                  0.661690
# 684         1358.2                  0.661189
# 305         1133.2                  0.660620
# 683         1357.5                  0.660537
# 682         1356.7                  0.660198
# 547         1267.2                  0.659499
# 560         1275.3                  0.658751
# 539         1262.3                  0.657314
# 561           1276                  0.656772
# 555         1272.2                  0.656507
# 553         1270.9                  0.654464
# 325         1143.2                  0.653965
# 548         1267.8                  0.653775
# 312         1136.7                  0.653713
# 557         1273.4                  0.652477
# 545           1266                  0.652173
# 552         1270.3                  0.652173
# 546         1266.6                  0.652173

# %% [markdown]
# # Seleksi Fitur Backward Selection dengan Random Forest Classifier

# %%
x_train_selected = x_train[features_mi.nlargest(300,columns="Mutual Information Value").iloc[0:300, 0]]
x_test_selected = x_test[features_mi.nlargest(300,columns="Mutual Information Value").iloc[0:300, 0]]

# %%
x_train_selected
# Out:
#        1139.7    1140.2    1141.7    1138.2    1138.7    1139.2    1140.7  \
# 16   0.492063  0.493875  0.500545  0.485824  0.487906  0.489890  0.496089
# 51   0.464010  0.466825  0.475396  0.454894  0.457810  0.460916  0.469729
# 183  0.586312  0.589698  0.600224  0.575629  0.579215  0.582786  0.593261
# 145  0.577506  0.580543  0.589776  0.568155  0.571318  0.574446  0.583619
# 40   0.402640  0.405209  0.413083  0.395286  0.397766  0.400044  0.407849
# ..        ...       ...       ...       ...       ...       ...       ...
# 103  0.543538  0.546104  0.554676  0.535210  0.538105  0.540964  0.549027
# 67   0.473749  0.476239  0.484654  0.465488  0.468295  0.471059  0.479081
# 117  0.503392  0.506553  0.516428  0.493610  0.496839  0.500089  0.509868
# 47   0.459436  0.462290  0.471228  0.450392  0.453445  0.456400  0.465182
# 172  0.499040  0.501932  0.510931  0.489965  0.492841  0.495920  0.504904
#
#        1141.2    1142.2    1132.2  ...      1333    1287.4    1207.6  \
# 16   0.498279  0.502916  0.464507  ...  0.634095  0.556184  0.569706
# 51   0.472565  0.478432  0.426489  ...  0.668614  0.555730  0.573913
# 183  0.596755  0.603650  0.540704  ...  0.810916  0.692120  0.707730
# 145  0.586613  0.592968  0.538299  ...  0.776353  0.669018  0.687148
# 40   0.410373  0.415739  0.370542  ...  0.579554  0.480875  0.503912
# ..        ...       ...       ...  ...       ...       ...       ...
# 103  0.551875  0.557337  0.508815  ...  0.730200  0.630338  0.643349
# 67   0.481982  0.487460  0.439093  ...  0.661354  0.556828  0.573851
# 117  0.513116  0.519892  0.462708  ...  0.740155  0.607688  0.629789
# 47   0.468146  0.474372  0.421441  ...  0.665888  0.550905  0.568889
# 172  0.507965  0.513851  0.460731  ...  0.695229  0.588282  0.603627
#
#        1346.2    1007.3    1212.7    1320.8    1610.4    1335.8    1336.5
# 16   0.665571  0.465651  0.568512  0.603703  0.842620  0.641125  0.642758
# 51   0.715781  0.425145  0.572004  0.623792  0.985393  0.679198  0.681701
# 183  0.855471  0.534954  0.706122  0.766246  1.073005  0.820799  0.823288
# 145  0.818788  0.536735  0.685297  0.734829  1.030706  0.785930  0.788264
# 40   0.621508  0.373607  0.501926  0.539874  0.869928  0.588804  0.591019
# ..        ...       ...       ...       ...       ...       ...       ...
# 103  0.769883  0.504845  0.642064  0.691601  0.982645  0.739100  0.741312
# 67   0.704487  0.439315  0.572048  0.619995  0.938691  0.671106  0.673352
# 117  0.795169  0.461213  0.627599  0.687533  1.094887  0.752581  0.755331
# 47   0.713774  0.420312  0.566776  0.620321  0.980873  0.676627  0.679137
# 172  0.737482  0.457784  0.602061  0.653910  0.955689  0.704771  0.707078
#
# [130 rows x 300 columns]

# %%
# calling the linear regression model
lreg = RandomForestClassifier(n_estimators=100)
sfs1 = sfs(lreg, k_features=60, forward=False, verbose=2, scoring='accuracy', n_jobs=-1)

# %%
# %%time

sfs1 = sfs1.fit(x_train_selected, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done 292 out of 300 | elapsed:   27.1s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:   27.4s finished
#
# [2022-06-06 19:48:19] Features: 299/60 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 290 out of 299 | elapsed:   20.2s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 299 out of 299 | elapsed:   20.4s finished
#
# [2022-06-06 19:48:39] Features: 298/60 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 289 out of 298 | elapsed:   20.5s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 298 out of 298 | elapsed:   20.7s finished
#
# [2022-06-06 19:49:00] Features: 297/60 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 287 out of 297 | elapsed:   20.1s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 297 out of 297 | elapsed:   20.4s finished
#
# [2022-06-06 19:49:20] Features: 296/60 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 286 out of 296 | elapsed:   19.7s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 296 out of 296 | elapsed:   20.0s finished
#
# [2022-06-06 19:49:40] Features: 295/60 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 284 out of 295 | elapsed:   20.0s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 295 out of 295 | elapsed:   20.3s finished
#
# [2022-06-06 19:50:01] Features: 294/60 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 283 out of 294 | elapsed:   20.0s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 294 out of 294 | elapsed:   20.3s finished
#
# [2022-06-06 19:50:21] Features: 293/60 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 281 out of 293 | elapsed:   19.8s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 293 out of 293 | elapsed:   20.0s finished
#
# [2022-06-06 19:50:41] Features: 292/60 -- score: 0.8923076923076924[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 280 out of 292 | elapsed:   19.4s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 292 out of 292 | elapsed:   19.9s finished
#
# [2022-06-06 19:51:01] Features: 291/60 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 278 out of 291 | elapsed:   19.4s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done 291 out of 291 | elapsed:   19.8s finished
#
# [2022-06-06 19:51:21] Features: 290/60 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done
parallel(n_jobs=-1)]: Done  61 out of  61 | elapsed:    5.2s finished
#
# [2022-06-06 20:32:22] Features: 60/60 -- score: 0.8615384615384617

# %%
feat_names = list(sfs1.k_feature_names_)
print("Fitur yang diambil adalah: ")
print(feat_names)
len(feat_names)
# Out:
# Fitur yang diambil adalah:
# ['1140.2', '1141.7', '1138.2', '1139.2', '1141.2', '1142.2', '1132.2', '1131.7', '1137.2', '1359.6', '1142.7', '1134.2', '1133.7', '1131.2', '1272.8', '1357.5', '1356.7', '1262.3', '1143.2', '1136.7', '1273.4', '1266', '1265.4', '1370.4', '1368.9', '1135.7', '1268.5', '1264.7', '1261.7', '1134.7', '1277.2', '1274.1', '1279.7', '1659.9', '1660.9', '1130.7', '1632.7', '1631.7', '1657.8', '1665.2', '1282.9', '999.9', '1278.5', '1294.4', '1282.3', '1354.6', '1690.2', '1363.9', '1172.7', '1670.6', '1178', '1316.1', '1349', '1178.5', '1299', '1284.8', '1338.5', '1363.2', '1293.8', '1339.9']
# 60

# %% [markdown]
# # Klasifikasi Random Forest Classifier

# %%
#buat n-fold cv
#cross validation 10-fold
cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %% [markdown]
# ## Testing Performa Model Random Forest Classifier

# %%
# %%time
#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
#n_feat = [10, 20, 30]
n_feat = [60]
n_trees = [100]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RFE data Train dengan 60 fitur dan 100 trees:1.0
# Akurasi model RFE data Test dengan 60 fitur dan 100 trees:0.96
# Precision model RFE data Train dengan 60 fitur dan 100 trees:1.0
# Precision model RFE data Test dengan 60 fitur dan 100 trees:0.96
# Recall model RFE data Train dengan 60 fitur dan 100 trees:1.0
# Recall model RFE data Test dengan 60 fitur dan 100 trees:0.96
#
# CPU times: user 1.37 s, sys: 24 ms, total: 1.39 s
# Wall time: 1.39 s

# %%
# %%time
#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
#n_feat = [10, 20, 30]
n_feat = [60]
n_trees = [150]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RFE data Train dengan 60 fitur dan 150 trees:1.0
# Akurasi model RFE data Test dengan 60 fitur dan 150 trees:0.95
# Precision model RFE data Train dengan 60 fitur dan 150 trees:1.0
# Precision model RFE data Test dengan 60 fitur dan 150 trees:0.95
# Recall model RFE data Train dengan 60 fitur dan 150 trees:1.0
# Recall model RFE data Test dengan 60 fitur dan 150 trees:0.95
#
# CPU times: user 1.99 s, sys: 24.1 ms, total: 2.02 s
# Wall time: 2.01 s

# %%
# %%time
#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
#n_feat = [10, 20, 30]
n_feat = [60]
n_trees = [200]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RFE data Train dengan 60 fitur dan 200 trees:1.0
# Akurasi model RFE data Test dengan 60 fitur dan 200 trees:0.96
# Precision model RFE data Train dengan 60 fitur dan 200 trees:1.0
# Precision model RFE data Test dengan 60 fitur dan 200 trees:0.96
# Recall model RFE data Train dengan 60 fitur dan 200 trees:1.0
# Recall model RFE data Test dengan 60 fitur dan 200 trees:0.96
#
# CPU times: user 2.66 s, sys: 36.1 ms, total: 2.7 s
# Wall time: 2.69 s

# %% [markdown]
# # Klasifikasi Support Vector Machine

# %% [markdown]
# Untuk train dan test set, serta cv-nya ambil dari yang Random Forest Classifier, sama aja

# %% [markdown]
# ## Testing Performa Model Support Vector Machine

# %%
# %%time
#tentukan metode scoring yang digunakan
scoring_svm = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur yang digunakan dalam proses klasifikasi SVM ini
#n_feat = [10, 20, 30]
n_feat = [60]

for nfeat in n_feat:     
    #ambil n fitur input hasil seleksi fitur Forward 
    x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
    x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

    #Create a Support Vector Classifier
    clf_svm = svm.SVC()

    #Train the model using the training sets
    clf_svm.fit(x_train_selected, y_train)
    y_pred_svm = clf_svm.predict(x_test_selected)

    #hitung score model dari data train
    scores_svm = cross_validate(clf_svm, x_train_selected, y_train, scoring=scoring_svm, cv=cv, return_train_score=True)

    print("akurasi model SVM data Train dengan " + str(nfeat) + " fitur: " 
          + str(round(scores_svm['train_acc'].mean(), 2)))
    print("akurasi model SVM data Test dengan " + str(nfeat) + " fitur: " 
          + str(round(metrics.accuracy_score(y_test, y_pred_svm), 2)))
    print("Precision model SVM data Train dengan " + str(nfeat) + " fitur:"
          + str(round(scores_svm['train_prec_micro'].mean(), 2)))
    print("Precision model SVM data Test dengan " + str(nfeat) + " fitur:"
          + str(round(metrics.precision_score(y_test, y_pred_svm, average='micro'), 2)))
    print("Recall model SVM data Train dengan " + str(nfeat) + " fitur:"
          + str(round(scores_svm['train_rec_micro'].mean(), 2)))
    print("Recall model SVM data Test dengan " + str(nfeat) + " fitur:"
          + str(round(metrics.recall_score(y_test, y_pred_svm, average='micro'), 2)))
    print(" ")
# Out:
# akurasi model SVM data Train dengan 60 fitur: 0.74
# akurasi model SVM data Test dengan 60 fitur: 0.62
# Precision model SVM data Train dengan 60 fitur:0.74
# Precision model SVM data Test dengan 60 fitur:0.62
# Recall model SVM data Train dengan 60 fitur:0.74
# Recall model SVM data Test dengan 60 fitur:0.62
#
# CPU times: user 115 ms, sys: 4.03 ms, total: 119 ms
# Wall time: 116 ms
