# %% [markdown]
# referensi https://www.analyticsvidhya.com/blog/2021/04/forward-feature-selection-and-its-implementation/

# %%
#instal library mlxtend
# %pip install mlxtend

# %%
#libraries buat seleksi fitur
import pandas as pd
import numpy as np
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import f_classif,SelectKBest 
from sklearn.feature_selection import mutual_info_classif

#libraries buat klasifikasi
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm

# %%
#import dataset
df = pd.read_csv('nirsMangga.csv')

# separate dataset into train and test
x_train, x_test, y_train, y_test = train_test_split(
    df.drop(labels=['No', 'Mango Cultivars', 'Vit C (mg/100g)', 'TA (mg/100g)', 'SSC (oBrix)', 'label'], axis=1),
    df['label'],
    test_size=0.3,
    random_state=0)

x_train.head()
# Out:
#         999.9    1000.3    1000.7    1001.1    1001.4    1001.8    1002.2  \
# 16   0.471459  0.471074  0.470934  0.470379  0.470260  0.469880  0.469497
# 51   0.433239  0.432622  0.432626  0.432379  0.431620  0.430710  0.430836
# 183  0.545045  0.544204  0.543792  0.543596  0.543338  0.542534  0.541493
# 145  0.545846  0.544815  0.544524  0.544631  0.544169  0.543143  0.542535
# 40   0.381048  0.380483  0.380541  0.380151  0.379599  0.379189  0.379009
#
#        1002.6      1003    1003.4  ...    2478.7    2481.1    2483.5  \
# 16   0.469435  0.469454  0.468998  ...  1.413537  1.415740  1.417568
# 51   0.430847  0.430188  0.429470  ...  1.601232  1.602877  1.604524
# 183  0.541139  0.541308  0.540831  ...  1.524657  1.525973  1.527454
# 145  0.542080  0.541842  0.541258  ...  1.421962  1.422955  1.423717
# 40   0.378722  0.378309  0.377719  ...  1.571125  1.572674  1.574303
#
#        2485.8    2488.2    2490.6      2493    2495.4    2497.8    2500.2
# 16   1.419698  1.421711  1.423070  1.424394  1.426121  1.427552  1.428625
# 51   1.605982  1.606778  1.607837  1.608756  1.609967  1.610900  1.611099
# 183  1.529518  1.530097  1.530315  1.530254  1.531191  1.532366  1.533183
# 145  1.424639  1.425080  1.425797  1.426503  1.427164  1.427838  1.428271
# 40   1.576075  1.577273  1.577980  1.578561  1.579334  1.580042  1.581424
#
# [5 rows x 1557 columns]

# %%
# %%time

# determine the mutual information
mutual_info = mutual_info_classif(x_train, y_train)
mutual_info
# Out:
# CPU times: user 4.31 s, sys: 42.7 ms, total: 4.36 s
# Wall time: 4.35 s
# array([0.63194121, 0.63677335, 0.63393088, ..., 0.5091611 , 0.49290951,
#        0.48903907])

# %%
x_train.columns
# Out:
# Index(['999.9', '1000.3', '1000.7', '1001.1', '1001.4', '1001.8', '1002.2',
#        '1002.6', '1003', '1003.4',
#        ...
#        '2478.7', '2481.1', '2483.5', '2485.8', '2488.2', '2490.6', '2493',
#        '2495.4', '2497.8', '2500.2'],
#       dtype='object', length=1557)

# %%
# Create features score, features p_value, and features name
features_mi = pd.DataFrame(mutual_info)
features = pd.DataFrame(x_train.columns)
features_mi = pd.concat([features, features_mi],axis=1)

#reset index, supaya tidak ada nilai nan di dataframe yg dibikin
features_mi.reset_index(drop=True, inplace=True)
features.reset_index(drop=True, inplace=True)

# Assign the column name
features_mi.columns = ["Input_Features", "Mutual Information Value"]

# Print features score
print(features_mi.nlargest(300,columns="Mutual Information Value"))
# Out:
#      Input_Features  Mutual Information Value
# 318          1139.7                  0.709039
# 319          1140.2                  0.703579
# 322          1141.7                  0.702486
# 315          1138.2                  0.700575
# 316          1138.7                  0.699476
# ...             ...                       ...
# 630          1320.8                  0.598360
# 983          1610.4                  0.598247
# 652          1335.8                  0.598080
# 653          1336.5                  0.597830
# 1068         1700.2                  0.597820
#
# [300 rows x 2 columns]

# %% [markdown]
# # Seleksi Fitur Backward Selection dengan Random Forest Classifier

# %%
x_train_selected = x_train[features_mi.nlargest(300,columns="Mutual Information Value").iloc[0:300, 0]]
x_test_selected = x_test[features_mi.nlargest(300,columns="Mutual Information Value").iloc[0:300, 0]]

# %%
x_train_selected
# Out:
#        1139.7    1140.2    1141.7    1138.2    1138.7    1139.2    1140.7  \
# 16   0.492063  0.493875  0.500545  0.485824  0.487906  0.489890  0.496089
# 51   0.464010  0.466825  0.475396  0.454894  0.457810  0.460916  0.469729
# 183  0.586312  0.589698  0.600224  0.575629  0.579215  0.582786  0.593261
# 145  0.577506  0.580543  0.589776  0.568155  0.571318  0.574446  0.583619
# 40   0.402640  0.405209  0.413083  0.395286  0.397766  0.400044  0.407849
# ..        ...       ...       ...       ...       ...       ...       ...
# 103  0.543538  0.546104  0.554676  0.535210  0.538105  0.540964  0.549027
# 67   0.473749  0.476239  0.484654  0.465488  0.468295  0.471059  0.479081
# 117  0.503392  0.506553  0.516428  0.493610  0.496839  0.500089  0.509868
# 47   0.459436  0.462290  0.471228  0.450392  0.453445  0.456400  0.465182
# 172  0.499040  0.501932  0.510931  0.489965  0.492841  0.495920  0.504904
#
#        1141.2    1142.2    1132.2  ...    1287.4    1207.6    1346.2  \
# 16   0.498279  0.502916  0.464507  ...  0.556184  0.569706  0.665571
# 51   0.472565  0.478432  0.426489  ...  0.555730  0.573913  0.715781
# 183  0.596755  0.603650  0.540704  ...  0.692120  0.707730  0.855471
# 145  0.586613  0.592968  0.538299  ...  0.669018  0.687148  0.818788
# 40   0.410373  0.415739  0.370542  ...  0.480875  0.503912  0.621508
# ..        ...       ...       ...  ...       ...       ...       ...
# 103  0.551875  0.557337  0.508815  ...  0.630338  0.643349  0.769883
# 67   0.481982  0.487460  0.439093  ...  0.556828  0.573851  0.704487
# 117  0.513116  0.519892  0.462708  ...  0.607688  0.629789  0.795169
# 47   0.468146  0.474372  0.421441  ...  0.550905  0.568889  0.713774
# 172  0.507965  0.513851  0.460731  ...  0.588282  0.603627  0.737482
#
#        1007.3    1212.7    1320.8    1610.4    1335.8    1336.5    1700.2
# 16   0.465651  0.568512  0.603703  0.842620  0.641125  0.642758  0.823174
# 51   0.425145  0.572004  0.623792  0.985393  0.679198  0.681701  0.944775
# 183  0.534954  0.706122  0.766246  1.073005  0.820799  0.823288  1.047135
# 145  0.536735  0.685297  0.734829  1.030706  0.785930  0.788264  1.004674
# 40   0.373607  0.501926  0.539874  0.869928  0.588804  0.591019  0.842687
# ..        ...       ...       ...       ...       ...       ...       ...
# 103  0.504845  0.642064  0.691601  0.982645  0.739100  0.741312  0.952670
# 67   0.439315  0.572048  0.619995  0.938691  0.671106  0.673352  0.903431
# 117  0.461213  0.627599  0.687533  1.094887  0.752581  0.755331  1.054435
# 47   0.420312  0.566776  0.620321  0.980873  0.676627  0.679137  0.939510
# 172  0.457784  0.602061  0.653910  0.955689  0.704771  0.707078  0.924606
#
# [130 rows x 300 columns]

# %%
# calling the linear regression model
lreg = RandomForestClassifier(n_estimators=100)
sfs1 = sfs(lreg, k_features=80, forward=False, verbose=2, scoring='accuracy', n_jobs=-1)

# %%
# %%time

sfs1 = sfs1.fit(x_train_selected, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done 292 out of 300 | elapsed:   27.3s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:   27.6s finished
#
# [2022-06-06 20:38:44] Features: 299/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 290 out of 299 | elapsed:   20.7s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 299 out of 299 | elapsed:   21.1s finished
#
# [2022-06-06 20:39:05] Features: 298/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 289 out of 298 | elapsed:   20.6s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 298 out of 298 | elapsed:   20.8s finished
#
# [2022-06-06 20:39:26] Features: 297/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 287 out of 297 | elapsed:   20.4s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 297 out of 297 | elapsed:   20.7s finished
#
# [2022-06-06 20:39:46] Features: 296/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 286 out of 296 | elapsed:   20.3s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 296 out of 296 | elapsed:   20.6s finished
#
# [2022-06-06 20:40:07] Features: 295/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 284 out of 295 | elapsed:   20.1s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 295 out of 295 | elapsed:   20.5s finished
#
# [2022-06-06 20:40:28] Features: 294/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 283 out of 294 | elapsed:   19.9s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 294 out of 294 | elapsed:   20.4s finished
#
# [2022-06-06 20:40:48] Features: 293/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 281 out of 293 | elapsed:   19.6s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 293 out of 293 | elapsed:   20.3s finished
#
# [2022-06-06 20:41:08] Features: 292/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 280 out of 292 | elapsed:   19.5s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 292 out of 292 | elapsed:   19.8s finished
#
# [2022-06-06 20:41:28] Features: 291/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 278 out of 291 | elapsed:   19.3s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done 291 out of 291 | elapsed:   20.0s finished
#
# [2022-06-06 20:41:48] Features: 290/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 277 out of 290 | elapsed:   19.4s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done 290 out of 290 | elapsed:   19.7s finished
#
# [2022-06-06 20:42:08] Features: 289/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 275 out of 289 | elapsed:   18.9s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 289 out of 289 | elapsed:   19.5s finished
#
# [2022-06-06 20:42:27] Features: 288/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 274 out of 288 | elapsed:   19.0s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 288 out of 288 | elapsed:   19.7s finished
#
# [2022-06-06 20:42:47] Features: 287/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 272 out of 287 | elapsed:   18.5s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 287 out of 287 | elapsed:   19.2s finished
#
# [2022-06-06 20:43:06] Features: 286/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 271 out of 286 | elapsed:   18.5s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 286 out of 286 | elapsed:   19.1s finished
#
# [2022-06-06 20:43:25] Features: 285/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 269 out of 285 | elapsed:   18.5s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 285 out of 285 | elapsed:   18.8s finished
#
# [2022-06-06 20:43:44] Features: 284/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 268 out of 284 | elapsed:   18.1s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 284 out of 284 | elapsed:   18.8s finished
#
# [2022-06-06 20:44:03] Features: 283/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 266 out of 283 | elapsed:   17.9s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 283 out of 283 | elapsed:   18.4s finished
#
# [2022-06-06 20:44:22] Features: 282/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 265 out of 282 | elapsed:   18.0s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 282 out of 282 | elapsed:   18.5s finished
#
# [2022-06-06 20:44:40] Features: 281/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 263 out of 281 | elapsed:   17.7s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 281 out of 281 | elapsed:   18.6s finished
#
# [2022-06-06 20:44:59] Features: 280/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 262 out of 280 | elapsed:   17.5s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 280 out of 280 | elapsed:   18.1s finished
#
# [2022-06-06 20:45:17] Features: 279/80 -- score: 0.8692307692307694[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 260 out of 279 | elapsed:   17.0s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 279 out of 279 | elapsed:   17.5s finished
#
# [2022-06-06 20:45:34] Features: 278/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 259 out of 278 | elapsed:   17.2s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done 278 out of 278 | elapsed:   17.8s finished
#
# [2022-06-06 20:45:52] Features: 277/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 257 out of 277 | elapsed:   16.7s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done 277 out of 277 | elapsed:   17.4s finished
#
# [2022-06-06 20:46:10] Features: 276/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 256 out of 276 | elapsed:   16.7s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done 276 out of 276 | elapsed:   17.5s finished
#
# [2022-06-06 20:46:27] Features: 275/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 254 out of 275 | elapsed:   16.9s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done 275 out of 275 | elapsed:   17.6s finished
#
# [2022-06-06 20:46:45] Features: 274/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 253 out of 274 | elapsed:   16.6s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done 274 out of 274 | elapsed:   17.1s finished
#
# [2022-06-06 20:47:02] Features: 273/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 251 out of 273 | elapsed:   16.4s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done 273 out of 273 | elapsed:   17.0s finished
#
# [2022-06-06 20:47:19] Features: 272/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 250 out of 272 | elapsed:   15.6s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done 272 out of 272 | elapsed:   16.2s finished
#
# [2022-06-06 20:47:35] Features: 271/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 248 out of 271 | elapsed:   16.0s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done 271 out of 271 | elapsed:   16.6s finished
#
# [2022-06-06 20:47:52] Features: 270/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 247 out of 270 | elapsed:   16.0s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done 270 out of 270 | elapsed:   16.9s finished
#
# [2022-06-06 20:48:09] Features: 269/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 245 out of 269 | elapsed:   15.2s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done 269 out of 269 | elapsed:   15.9s finished
#
# [2022-06-06 20:48:25] Features: 268/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 244 out of 268 | elapsed:   15.0s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done 268 out of 268 | elapsed:   15.6s finished
#
# [2022-06-06 20:48:40] Features: 267/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 242 out of 267 | elapsed:   15.0s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done 267 out of 267 | elapsed:   15.6s finished
#
# [2022-06-06 20:48:56] Features: 266/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 241 out of 266 | elapsed:   14.6s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done 266 out of 266 | elapsed:   15.3s finished
#
# [2022-06-06 20:49:11] Features: 265/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 239 out of 265 | elapsed:   14.6s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done 265 out of 265 | elapsed:   15.4s finished
#
# [2022-06-06 20:49:27] Features: 264/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 238 out of 264 | elapsed:   13.6s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done 264 out of 264 | elapsed:   14.5s finished
#
# [2022-06-06 20:49:41] Features: 263/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 236 out of 263 | elapsed:   13.3s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done 263 out of 263 | elapsed:   14.6s finished
#
# [2022-06-06 20:49:56] Features: 262/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 235 out of 262 | elapsed:   13.2s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done 262 out of 262 | elapsed:   14.1s finished
#
# [2022-06-06 20:50:10] Features: 261/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 233 out of 261 | elapsed:   13.3s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done 261 out of 261 | elapsed:   14.2s finished
#
# [2022-06-06 20:50:24] Features: 260/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 232 out of 260 | elapsed:   13.4s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done 260 out of 260 | elapsed:   14.2s finished
#
# [2022-06-06 20:50:38] Features: 259/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 230 out of 259 | elapsed:   12.6s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done 259 out of 259 | elapsed:   13.7s finished
#
# [2022-06-06 20:50:52] Features: 258/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 229 out of 258 | elapsed:   12.2s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done 258 out of 258 | elapsed:   13.7s finished
#
# [2022-06-06 20:51:06] Features: 257/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 227 out of 257 | elapsed:   12.4s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done 257 out of 257 | elapsed:   13.3s finished
#
# [2022-06-06 20:51:19] Features: 256/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 226 out of 256 | elapsed:   11.4s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done 256 out of 256 | elapsed:   12.7s finished
#
# [2022-06-06 20:51:32] Features: 255/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 224 out of 255 | elapsed:   11.4s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done 255 out of 255 | elapsed:   12.6s finished
#
# [2022-06-06 20:51:44] Features: 254/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 223 out of 254 | elapsed:   11.4s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done 254 out of 254 | elapsed:   12.6s finished
#
# [2022-06-06 20:51:57] Features: 253/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 221 out of 253 | elapsed:   12.4s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done 253 out of 253 | elapsed:   13.6s finished
#
# [2022-06-06 20:52:11] Features: 252/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 220 out of 252 | elapsed:   11.8s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done 252 out of 252 | elapsed:   12.9s finished
#
# [2022-06-06 20:52:23] Features: 251/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 218 out of 251 | elapsed:   11.1s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done 251 out of 251 | elapsed:   12.4s finished
#
# [2022-06-06 20:52:36] Features: 250/80 -- score: 0.8692307692307694[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 217 out of 250 | elapsed:   10.9s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:   12.3s finished
#
# [2022-06-06 20:52:48] Features: 249/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 215 out of 249 | elapsed:   11.3s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done 249 out of 249 | elapsed:   12.6s finished
#
# [2022-06-06 20:53:01] Features: 248/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 214 out of 248 | elapsed:   10.7s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done 248 out of 248 | elapsed:   12.1s finished
#
# [2022-06-06 20:53:13] Features: 247/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 212 out of 247 | elapsed:   10.5s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done 247 out of 247 | elapsed:   11.9s finished
#
# [2022-06-06 20:53:25] Features: 246/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 211 out of 246 | elapsed:   10.8s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done 246 out of 246 | elapsed:   12.1s finished
#
# [2022-06-06 20:53:37] Features: 245/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 209 out of 245 | elapsed:   10.5s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done 245 out of 245 | elapsed:   12.0s finished
#
# [2022-06-06 20:53:49] Features: 244/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 208 out of 244 | elapsed:   10.8s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done 244 out of 244 | elapsed:   12.0s finished
#
# [2022-06-06 20:54:01] Features: 243/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 206 out of 243 | elapsed:   10.3s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done 243 out of 243 | elapsed:   11.8s finished
#
# [2022-06-06 20:54:13] Features: 242/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 205 out of 242 | elapsed:   10.4s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done 242 out of 242 | elapsed:   12.0s finished
#
# [2022-06-06 20:54:25] Features: 241/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 203 out of 241 | elapsed:   10.5s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done 241 out of 241 | elapsed:   12.1s finished
#
# [2022-06-06 20:54:37] Features: 240/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 202 out of 240 | elapsed:   10.6s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done 240 out of 240 | elapsed:   12.1s finished
#
# [2022-06-06 20:54:49] Features: 239/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 200 out of 239 | elapsed:   10.4s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done 239 out of 239 | elapsed:   11.9s finished
#
# [2022-06-06 20:55:01] Features: 238/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 199 out of 238 | elapsed:   10.6s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done 238 out of 238 | elapsed:   12.0s finished
#
# [2022-06-06 20:55:13] Features: 237/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 197 out of 237 | elapsed:   10.2s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done 237 out of 237 | elapsed:   12.0s finished
#
# [2022-06-06 20:55:25] Features: 236/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 196 out of 236 | elapsed:   10.4s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done 236 out of 236 | elapsed:   12.1s finished
#
# [2022-06-06 20:55:37] Features: 235/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 194 out of 235 | elapsed:   10.0s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done 235 out of 235 | elapsed:   11.7s finished
#
# [2022-06-06 20:55:49] Features: 234/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 193 out of 234 | elapsed:   10.1s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done 234 out of 234 | elapsed:   11.9s finished
#
# [2022-06-06 20:56:01] Features: 233/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 191 out of 233 | elapsed:    9.8s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done 233 out of 233 | elapsed:   11.6s finished
#
# [2022-06-06 20:56:13] Features: 232/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 190 out of 232 | elapsed:    9.9s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done 232 out of 232 | elapsed:   11.8s finished
#
# [2022-06-06 20:56:24] Features: 231/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 188 out of 231 | elapsed:   10.0s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done 231 out of 231 | elapsed:   11.8s finished
#
# [2022-06-06 20:56:36] Features: 230/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 187 out of 230 | elapsed:    9.7s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done 230 out of 230 | elapsed:   11.5s finished
#
# [2022-06-06 20:56:48] Features: 229/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 185 out of 229 | elapsed:    9.7s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done 229 out of 229 | elapsed:   11.6s finished
#
# [2022-06-06 20:56:59] Features: 228/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 184 out of 228 | elapsed:    9.5s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done 228 out of 228 | elapsed:   11.5s finished
#
# [2022-06-06 20:57:11] Features: 227/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 182 out of 227 | elapsed:    9.5s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done 227 out of 227 | elapsed:   11.5s finished
#
# [2022-06-06 20:57:22] Features: 226/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 181 out of 226 | elapsed:    9.5s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 226 out of 226 | elapsed:   11.4s finished
#
# [2022-06-06 20:57:34] Features: 225/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 179 out of 225 | elapsed:    9.5s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 225 out of 225 | elapsed:   11.2s finished
#
# [2022-06-06 20:57:45] Features: 224/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 178 out of 224 | elapsed:    9.4s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 224 out of 224 | elapsed:   11.4s finished
#
# [2022-06-06 20:57:56] Features: 223/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 176 out of 223 | elapsed:    9.2s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done 223 out of 223 | elapsed:   11.3s finished
#
# [2022-06-06 20:58:08] Features: 222/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 175 out of 222 | elapsed:    9.1s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 222 out of 222 | elapsed:   11.2s finished
#
# [2022-06-06 20:58:19] Features: 221/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 173 out of 221 | elapsed:    9.0s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done 221 out of 221 | elapsed:   11.2s finished
#
# [2022-06-06 20:58:30] Features: 220/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 172 out of 220 | elapsed:    9.3s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done 220 out of 220 | elapsed:   11.4s finished
#
# [2022-06-06 20:58:41] Features: 219/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 170 out of 219 | elapsed:    9.0s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done 219 out of 219 | elapsed:   11.3s finished
#
# [2022-06-06 20:58:53] Features: 218/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 169 out of 218 | elapsed:    9.3s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done 218 out of 218 | elapsed:   11.6s finished
#
# [2022-06-06 20:59:04] Features: 217/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 167 out of 217 | elapsed:    8.8s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done 217 out of 217 | elapsed:   11.3s finished
#
# [2022-06-06 20:59:16] Features: 216/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 166 out of 216 | elapsed:    8.8s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done 216 out of 216 | elapsed:   11.1s finished
#
# [2022-06-06 20:59:27] Features: 215/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 164 out of 215 | elapsed:    8.9s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done 215 out of 215 | elapsed:   11.5s finished
#
# [2022-06-06 20:59:38] Features: 214/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 163 out of 214 | elapsed:    9.2s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done 214 out of 214 | elapsed:   11.6s finished
#
# [2022-06-06 20:59:50] Features: 213/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 161 out of 213 | elapsed:    9.1s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done 213 out of 213 | elapsed:   11.4s finished
#
# [2022-06-06 21:00:01] Features: 212/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 160 out of 212 | elapsed:    8.7s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done 212 out of 212 | elapsed:   11.2s finished
#
# [2022-06-06 21:00:13] Features: 211/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 158 out of 211 | elapsed:    8.7s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done 211 out of 211 | elapsed:   11.2s finished
#
# [2022-06-06 21:00:24] Features: 210/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 157 out of 210 | elapsed:    8.6s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done 210 out of 210 | elapsed:   11.1s finished
#
# [2022-06-06 21:00:35] Features: 209/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 155 out of 209 | elapsed:    8.6s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done 209 out of 209 | elapsed:   11.1s finished
#
# [2022-06-06 21:00:46] Features: 208/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 154 out of 208 | elapsed:    8.6s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done 208 out of 208 | elapsed:   11.2s finished
#
# [2022-06-06 21:00:57] Features: 207/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 152 out of 207 | elapsed:    8.5s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done 207 out of 207 | elapsed:   11.1s finished
#
# [2022-06-06 21:01:08] Features: 206/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 151 out of 206 | elapsed:    8.3s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done 206 out of 206 | elapsed:   11.0s finished
#
# [2022-06-06 21:01:19] Features: 205/80 -- score: 0.8692307692307694[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 149 out of 205 | elapsed:    8.5s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done 205 out of 205 | elapsed:   11.2s finished
#
# [2022-06-06 21:01:30] Features: 204/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 148 out of 204 | elapsed:    8.5s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done 204 out of 204 | elapsed:   11.1s finished
#
# [2022-06-06 21:01:42] Features: 203/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 146 out of 203 | elapsed:    8.2s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done 203 out of 203 | elapsed:   10.9s finished
#
# [2022-06-06 21:01:52] Features: 202/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 145 out of 202 | elapsed:    8.3s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done 202 out of 202 | elapsed:   11.0s finished
#
# [2022-06-06 21:02:03] Features: 201/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 143 out of 201 | elapsed:    8.0s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done 201 out of 201 | elapsed:   10.9s finished
#
# [2022-06-06 21:02:14] Features: 200/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 142 out of 200 | elapsed:    7.9s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:   10.7s finished
#
# [2022-06-06 21:02:25] Features: 199/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 140 out of 199 | elapsed:    8.2s remaining:    3.4s
# [Parallel(n_jobs=-1)]: Done 199 out of 199 | elapsed:   11.1s finished
#
# [2022-06-06 21:02:36] Features: 198/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 139 out of 198 | elapsed:    8.1s remaining:    3.4s
# [Parallel(n_jobs=-1)]: Done 198 out of 198 | elapsed:   10.9s finished
#
# [2022-06-06 21:02:47] Features: 197/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 137 out of 197 | elapsed:    7.8s remaining:    3.4s
# [Parallel(n_jobs=-1)]: Done 197 out of 197 | elapsed:   10.7s finished
#
# [2022-06-06 21:02:58] Features: 196/80 -- score: 0.8692307692307694[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 136 out of 196 | elapsed:    7.7s remaining:    3.4s
# [Parallel(n_jobs=-1)]: Done 196 out of 196 | elapsed:   10.8s finished
#
# [2022-06-06 21:03:09] Features: 195/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 134 out of 195 | elapsed:    8.0s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done 195 out of 195 | elapsed:   11.1s finished
#
# [2022-06-06 21:03:20] Features: 194/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 133 out of 194 | elapsed:    7.8s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done 194 out of 194 | elapsed:   10.9s finished
#
# [2022-06-06 21:03:31] Features: 193/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 131 out of 193 | elapsed:    7.9s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done 193 out of 193 | elapsed:   11.0s finished
#
# [2022-06-06 21:03:42] Features: 192/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 130 out of 192 | elapsed:    7.7s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done 192 out of 192 | elapsed:   10.9s finished
#
# [2022-06-06 21:03:53] Features: 191/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 128 out of 191 | elapsed:    7.6s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done 191 out of 191 | elapsed:   10.8s finished
#
# [2022-06-06 21:04:03] Features: 190/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 127 out of 190 | elapsed:    7.5s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done 190 out of 190 | elapsed:   10.8s finished
#
# [2022-06-06 21:04:14] Features: 189/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 125 out of 189 | elapsed:    7.6s remaining:    3.9s
# [Parallel(n_jobs=-1)]: Done 189 out of 189 | elapsed:   11.0s finished
#
# [2022-06-06 21:04:25] Features: 188/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 124 out of 188 | elapsed:    7.5s remaining:    3.9s
# [Parallel(n_jobs=-1)]: Done 188 out of 188 | elapsed:   10.8s finished
#
# [2022-06-06 21:04:36] Features: 187/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 122 out of 187 | elapsed:    7.4s remaining:    3.9s
# [Parallel(n_jobs=-1)]: Done 187 out of 187 | elapsed:   10.9s finished
#
# [2022-06-06 21:04:47] Features: 186/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 121 out of 186 | elapsed:    7.4s remaining:    4.0s
# [Parallel(n_jobs=-1)]: Done 186 out of 186 | elapsed:   10.9s finished
#
# [2022-06-06 21:04:58] Features: 185/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 119 out of 185 | elapsed:    7.3s remaining:    4.0s
# [Parallel(n_jobs=-1)]: Done 185 out of 185 | elapsed:   10.8s finished
#
# [2022-06-06 21:05:09] Features: 184/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 118 out of 184 | elapsed:    7.2s remaining:    4.0s
# [Parallel(n_jobs=-1)]: Done 184 out of 184 | elapsed:   10.8s finished
#
# [2022-06-06 21:05:20] Features: 183/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 116 out of 183 | elapsed:    7.4s remaining:    4.2s
# [Parallel(n_jobs=-1)]: Done 183 out of 183 | elapsed:   10.8s finished
#
# [2022-06-06 21:05:30] Features: 182/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 115 out of 182 | elapsed:    7.1s remaining:    4.1s
# [Parallel(n_jobs=-1)]: Done 182 out of 182 | elapsed:   10.6s finished
#
# [2022-06-06 21:05:41] Features: 181/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 113 out of 181 | elapsed:    7.1s remaining:    4.2s
# [Parallel(n_jobs=-1)]: Done 181 out of 181 | elapsed:   10.7s finished
#
# [2022-06-06 21:05:52] Features: 180/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 112 out of 180 | elapsed:    6.9s remaining:    4.2s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   10.7s finished
#
# [2022-06-06 21:06:02] Features: 179/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 110 out of 179 | elapsed:    6.9s remaining:    4.3s
# [Parallel(n_jobs=-1)]: Done 179 out of 179 | elapsed:   10.6s finished
#
# [2022-06-06 21:06:13] Features: 178/80 -- score: 0.8692307692307694[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 109 out of 178 | elapsed:    6.9s remaining:    4.4s
# [Parallel(n_jobs=-1)]: Done 178 out of 178 | elapsed:   10.7s finished
#
# [2022-06-06 21:06:24] Features: 177/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 107 out of 177 | elapsed:    6.9s remaining:    4.5s
# [Parallel(n_jobs=-1)]: Done 177 out of 177 | elapsed:   10.6s finished
#
# [2022-06-06 21:06:34] Features: 176/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 106 out of 176 | elapsed:    6.6s remaining:    4.4s
# [Parallel(n_jobs=-1)]: Done 176 out of 176 | elapsed:   10.4s finished
#
# [2022-06-06 21:06:45] Features: 175/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 104 out of 175 | elapsed:    6.5s remaining:    4.5s
# [Parallel(n_jobs=-1)]: Done 175 out of 175 | elapsed:   10.5s finished
#
# [2022-06-06 21:06:55] Features: 174/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 103 out of 174 | elapsed:    6.5s remaining:    4.5s
# [Parallel(n_jobs=-1)]: Done 174 out of 174 | elapsed:   10.6s finished
#
# [2022-06-06 21:07:06] Features: 173/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 101 out of 173 | elapsed:    6.5s remaining:    4.6s
# [Parallel(n_jobs=-1)]: Done 173 out of 173 | elapsed:   10.5s finished
#
# [2022-06-06 21:07:16] Features: 172/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 100 out of 172 | elapsed:    6.3s remaining:    4.6s
# [Parallel(n_jobs=-1)]: Done 172 out of 172 | elapsed:   10.4s finished
#
# [2022-06-06 21:07:27] Features: 171/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done  98 out of 171 | elapsed:    6.4s remaining:    4.8s
# [Parallel(n_jobs=-1)]: Done 171 out of 171 | elapsed:   10.5s finished
#
# [2022-06-06 21:07:37] Features: 170/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done  97 out of 170 | elapsed:    6.4s remaining:    4.8s
# [Parallel(n_jobs=-1)]: Done 170 out of 170 | elapsed:   10.6s finished
#
# [2022-06-06 21:07:48] Features: 169/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done  95 out of 169 | elapsed:    6.4s remaining:    5.0s
# [Parallel(n_jobs=-1)]: Done 169 out of 169 | elapsed:   10.5s finished
#
# [2022-06-06 21:07:58] Features: 168/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done  94 out of 168 | elapsed:    6.3s remaining:    4.9s
# [Parallel(n_jobs=-1)]: Done 168 out of 168 | elapsed:   10.4s finished
#
# [2022-06-06 21:08:09] Features: 167/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done  92 out of 167 | elapsed:    6.1s remaining:    4.9s
# [Parallel(n_jobs=-1)]: Done 167 out of 167 | elapsed:   10.3s finished
#
# ...
# [Parallel(n_jobs=-1)]: Done 123 out of 123 | elapsed:    9.1s finished
#
# [2022-06-06 21:15:30] Features: 122/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of 122 | elapsed:    2.4s remaining:    9.5s
# [Parallel(n_jobs=-1)]: Done  87 out of 122 | elapsed:    6.6s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done 122 out of 122 | elapsed:    8.8s finished
#
# [2022-06-06 21:15:39] Features: 121/80 -- score: 0.8692307692307694[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of 121 | elapsed:    2.2s remaining:    9.4s
# [Parallel(n_jobs=-1)]: Done  84 out of 121 | elapsed:    6.3s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done 121 out of 121 | elapsed:    8.8s finished
#
# [2022-06-06 21:15:48] Features: 120/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of 120 | elapsed:    2.2s remaining:    9.8s
# [Parallel(n_jobs=-1)]: Done  83 out of 120 | elapsed:    6.3s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    8.7s finished
#
# [2022-06-06 21:15:56] Features: 119/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of 119 | elapsed:    2.0s remaining:   10.1s
# [Parallel(n_jobs=-1)]: Done  80 out of 119 | elapsed:    6.3s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done 119 out of 119 | elapsed:    8.9s finished
#
# [2022-06-06 21:16:05] Features: 118/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of 118 | elapsed:    2.0s remaining:   10.3s
# [Parallel(n_jobs=-1)]: Done  79 out of 118 | elapsed:    6.1s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done 118 out of 118 | elapsed:    8.8s finished
#
# [2022-06-06 21:16:14] Features: 117/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of 117 | elapsed:    2.0s remaining:   11.6s
# [Parallel(n_jobs=-1)]: Done  76 out of 117 | elapsed:    6.0s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done 117 out of 117 | elapsed:    8.9s finished
#
# [2022-06-06 21:16:23] Features: 116/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of 116 | elapsed:    1.8s remaining:   11.3s
# [Parallel(n_jobs=-1)]: Done  75 out of 116 | elapsed:    5.8s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done 116 out of 116 | elapsed:    8.5s finished
#
# [2022-06-06 21:16:32] Features: 115/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of 115 | elapsed:    1.8s remaining:   13.1s
# [Parallel(n_jobs=-1)]: Done  72 out of 115 | elapsed:    5.8s remaining:    3.4s
# [Parallel(n_jobs=-1)]: Done 115 out of 115 | elapsed:    8.7s finished
#
# [2022-06-06 21:16:40] Features: 114/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of 114 | elapsed:    1.6s remaining:   12.2s
# [Parallel(n_jobs=-1)]: Done  71 out of 114 | elapsed:    5.6s remaining:    3.4s
# [Parallel(n_jobs=-1)]: Done 114 out of 114 | elapsed:    8.5s finished
#
# [2022-06-06 21:16:49] Features: 113/80 -- score: 0.8692307692307694[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of 113 | elapsed:    1.5s remaining:   13.5s
# [Parallel(n_jobs=-1)]: Done  68 out of 113 | elapsed:    5.5s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done 113 out of 113 | elapsed:    8.5s finished
#
# [2022-06-06 21:16:57] Features: 112/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of 112 | elapsed:    1.4s remaining:   14.5s
# [Parallel(n_jobs=-1)]: Done  67 out of 112 | elapsed:    5.4s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done 112 out of 112 | elapsed:    8.4s finished
#
# [2022-06-06 21:17:06] Features: 111/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of 111 | elapsed:    1.3s remaining:   16.4s
# [Parallel(n_jobs=-1)]: Done  64 out of 111 | elapsed:    5.2s remaining:    3.8s
# [Parallel(n_jobs=-1)]: Done 111 out of 111 | elapsed:    8.3s finished
#
# [2022-06-06 21:17:14] Features: 110/80 -- score: 0.8692307692307694[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of 110 | elapsed:    1.1s remaining:   16.7s
# [Parallel(n_jobs=-1)]: Done  63 out of 110 | elapsed:    5.1s remaining:    3.8s
# [Parallel(n_jobs=-1)]: Done 110 out of 110 | elapsed:    8.3s finished
#
# [2022-06-06 21:17:22] Features: 109/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of 109 | elapsed:    1.0s remaining:   21.8s
# [Parallel(n_jobs=-1)]: Done  60 out of 109 | elapsed:    4.9s remaining:    4.0s
# [Parallel(n_jobs=-1)]: Done 109 out of 109 | elapsed:    8.3s finished
#
# [2022-06-06 21:17:31] Features: 108/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of 108 | elapsed:    1.1s remaining:   28.3s
# [Parallel(n_jobs=-1)]: Done  59 out of 108 | elapsed:    4.8s remaining:    4.0s
# [Parallel(n_jobs=-1)]: Done 108 out of 108 | elapsed:    8.2s finished
#
# [2022-06-06 21:17:39] Features: 107/80 -- score: 0.8692307692307694[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of 107 | elapsed:    0.8s remaining:   40.9s
# [Parallel(n_jobs=-1)]: Done  56 out of 107 | elapsed:    4.8s remaining:    4.3s
# [Parallel(n_jobs=-1)]: Done 107 out of 107 | elapsed:    8.3s finished
#
# [2022-06-06 21:17:47] Features: 106/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  55 out of 106 | elapsed:    4.4s remaining:    4.1s
# [Parallel(n_jobs=-1)]: Done 106 out of 106 | elapsed:    8.0s finished
#
# [2022-06-06 21:17:55] Features: 105/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  52 out of 105 | elapsed:    4.5s remaining:    4.5s
# [Parallel(n_jobs=-1)]: Done 105 out of 105 | elapsed:    8.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 105 out of 105 | elapsed:    8.1s finished
#
# [2022-06-06 21:18:03] Features: 104/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  51 out of 104 | elapsed:    4.3s remaining:    4.5s
# [Parallel(n_jobs=-1)]: Done 104 out of 104 | elapsed:    8.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 104 out of 104 | elapsed:    8.0s finished
#
# [2022-06-06 21:18:11] Features: 103/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  48 out of 103 | elapsed:    4.3s remaining:    4.9s
# [Parallel(n_jobs=-1)]: Done 100 out of 103 | elapsed:    7.8s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 103 out of 103 | elapsed:    7.9s finished
#
# [2022-06-06 21:18:19] Features: 102/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  47 out of 102 | elapsed:    4.0s remaining:    4.6s
# [Parallel(n_jobs=-1)]: Done  99 out of 102 | elapsed:    7.6s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 102 out of 102 | elapsed:    7.8s finished
#
# [2022-06-06 21:18:27] Features: 101/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  44 out of 101 | elapsed:    3.7s remaining:    4.9s
# [Parallel(n_jobs=-1)]: Done  95 out of 101 | elapsed:    7.3s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 101 out of 101 | elapsed:    7.7s finished
#
# [2022-06-06 21:18:35] Features: 100/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  43 out of 100 | elapsed:    3.8s remaining:    5.1s
# [Parallel(n_jobs=-1)]: Done  94 out of 100 | elapsed:    7.4s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    7.8s finished
#
# [2022-06-06 21:18:42] Features: 99/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  40 out of  99 | elapsed:    3.4s remaining:    5.0s
# [Parallel(n_jobs=-1)]: Done  90 out of  99 | elapsed:    7.0s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  99 out of  99 | elapsed:    7.6s finished
#
# [2022-06-06 21:18:50] Features: 98/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  39 out of  98 | elapsed:    3.5s remaining:    5.2s
# [Parallel(n_jobs=-1)]: Done  89 out of  98 | elapsed:    7.1s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  98 out of  98 | elapsed:    7.7s finished
#
# [2022-06-06 21:18:58] Features: 97/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  36 out of  97 | elapsed:    3.3s remaining:    5.5s
# [Parallel(n_jobs=-1)]: Done  85 out of  97 | elapsed:    6.9s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done  97 out of  97 | elapsed:    7.6s finished
#
# [2022-06-06 21:19:05] Features: 96/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  96 | elapsed:    3.2s remaining:    5.6s
# [Parallel(n_jobs=-1)]: Done  84 out of  96 | elapsed:    6.8s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed:    7.5s finished
#
# [2022-06-06 21:19:13] Features: 95/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  95 | elapsed:    3.0s remaining:    5.9s
# [Parallel(n_jobs=-1)]: Done  80 out of  95 | elapsed:    6.5s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  95 out of  95 | elapsed:    7.5s finished
#
# [2022-06-06 21:19:21] Features: 94/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  94 | elapsed:    2.9s remaining:    5.9s
# [Parallel(n_jobs=-1)]: Done  79 out of  94 | elapsed:    6.4s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  94 out of  94 | elapsed:    7.4s finished
#
# [2022-06-06 21:19:28] Features: 93/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  93 | elapsed:    2.7s remaining:    6.2s
# [Parallel(n_jobs=-1)]: Done  75 out of  93 | elapsed:    6.2s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done  93 out of  93 | elapsed:    7.5s finished
#
# [2022-06-06 21:19:35] Features: 92/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  92 | elapsed:    2.6s remaining:    6.2s
# [Parallel(n_jobs=-1)]: Done  74 out of  92 | elapsed:    6.0s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done  92 out of  92 | elapsed:    7.2s finished
#
# [2022-06-06 21:19:43] Features: 91/80 -- score: 0.8846153846153847[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 out of  91 | elapsed:    2.4s remaining:    6.7s
# [Parallel(n_jobs=-1)]: Done  70 out of  91 | elapsed:    5.8s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done  91 out of  91 | elapsed:    7.2s finished
#
# [2022-06-06 21:19:50] Features: 90/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  90 | elapsed:    2.4s remaining:    7.1s
# [Parallel(n_jobs=-1)]: Done  69 out of  90 | elapsed:    5.9s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done  90 out of  90 | elapsed:    7.3s finished
#
# [2022-06-06 21:19:57] Features: 89/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  89 | elapsed:    2.0s remaining:    7.1s
# [Parallel(n_jobs=-1)]: Done  65 out of  89 | elapsed:    5.5s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  89 out of  89 | elapsed:    7.2s finished
#
# [2022-06-06 21:20:04] Features: 88/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  88 | elapsed:    2.1s remaining:    7.7s
# [Parallel(n_jobs=-1)]: Done  64 out of  88 | elapsed:    5.4s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  88 out of  88 | elapsed:    7.3s finished
#
# [2022-06-06 21:20:12] Features: 87/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  87 | elapsed:    1.8s remaining:    7.9s
# [Parallel(n_jobs=-1)]: Done  60 out of  87 | elapsed:    5.1s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done  87 out of  87 | elapsed:    7.0s finished
#
# [2022-06-06 21:20:19] Features: 86/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  86 | elapsed:    1.8s remaining:    8.3s
# [Parallel(n_jobs=-1)]: Done  59 out of  86 | elapsed:    5.1s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done  86 out of  86 | elapsed:    7.0s finished
#
# [2022-06-06 21:20:26] Features: 85/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  85 | elapsed:    1.5s remaining:    9.2s
# [Parallel(n_jobs=-1)]: Done  55 out of  85 | elapsed:    4.9s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done  85 out of  85 | elapsed:    7.1s finished
#
# [2022-06-06 21:20:33] Features: 84/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  84 | elapsed:    1.5s remaining:    9.8s
# [Parallel(n_jobs=-1)]: Done  54 out of  84 | elapsed:    4.6s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    6.8s finished
#
# [2022-06-06 21:20:40] Features: 83/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  83 | elapsed:    1.3s remaining:   11.9s
# [Parallel(n_jobs=-1)]: Done  50 out of  83 | elapsed:    4.4s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done  83 out of  83 | elapsed:    6.7s finished
#
# [2022-06-06 21:20:46] Features: 82/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  82 | elapsed:    1.2s remaining:   12.7s
# [Parallel(n_jobs=-1)]: Done  49 out of  82 | elapsed:    4.2s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done  82 out of  82 | elapsed:    6.5s finished
#
# [2022-06-06 21:20:53] Features: 81/80 -- score: 0.876923076923077[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  81 | elapsed:    1.0s remaining:   18.4s
# [Parallel(n_jobs=-1)]: Done  45 out of  81 | elapsed:    4.1s remaining:    3.3s
# CPU times: user 32min 55s, sys: 27 s, total: 33min 22s
# Wall time: 42min 44s
# [Parallel(n_jobs=-1)]: Done  81 out of  81 | elapsed:    6.7s finished
#
# [2022-06-06 21:20:59] Features: 80/80 -- score: 0.876923076923077

# %%
feat_names = list(sfs1.k_feature_names_)
print("Fitur yang diambil adalah: ")
print(feat_names)
len(feat_names)
# Out:
# Fitur yang diambil adalah:
# ['1139.7', '1140.2', '1141.7', '1138.2', '1140.7', '1141.2', '1142.2', '1137.7', '1131.7', '1137.2', '1142.7', '1133.7', '1361', '1131.2', '1272.8', '1133.2', '1356.7', '1275.3', '1262.3', '1276', '1136.7', '1273.4', '1266', '1270.3', '1266.6', '1274.7', '1269.1', '1369.6', '1263.5', '1271.6', '1361.7', '1135.7', '1276.6', '1268.5', '1134.7', '1662', '1274.1', '1264.1', '1279.7', '1135.2', '1659.9', '1660.9', '1632.7', '1663.1', '1368.2', '1654.6', '1651.4', '1657.8', '1652.5', '1628.6', '1653.5', '1000.7', '1665.2', '1282.9', '1371.1', '1650.4', '1356', '1001.8', '1668.4', '1694.6', '1001.1', '1693.5', '1373.3', '1296.4', '1348.3', '1330.3', '1299', '1674.9', '1318.1', '1686.9', '1321.5', '1331', '1351.1', '1648.3', '1338.5', '1316.8', '1322.1', '1646.2', '1684.7', '1203.1']
# 80

# %% [markdown]
# # Klasifikasi Random Forest Classifier

# %%
#buat n-fold cv
#cross validation 10-fold
cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %% [markdown]
# ## Testing Performa Model Random Forest Classifier

# %%
# %%time
#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
#n_feat = [10, 20, 30]
n_feat = [80]
n_trees = [100]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RFE data Train dengan 80 fitur dan 100 trees:1.0
# Akurasi model RFE data Test dengan 80 fitur dan 100 trees:0.95
# Precision model RFE data Train dengan 80 fitur dan 100 trees:1.0
# Precision model RFE data Test dengan 80 fitur dan 100 trees:0.95
# Recall model RFE data Train dengan 80 fitur dan 100 trees:1.0
# Recall model RFE data Test dengan 80 fitur dan 100 trees:0.95
#
# CPU times: user 1.43 s, sys: 11.9 ms, total: 1.45 s
# Wall time: 1.44 s

# %%
# %%time
#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
#n_feat = [10, 20, 30]
n_feat = [80]
n_trees = [150]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RFE data Train dengan 80 fitur dan 150 trees:1.0
# Akurasi model RFE data Test dengan 80 fitur dan 150 trees:0.95
# Precision model RFE data Train dengan 80 fitur dan 150 trees:1.0
# Precision model RFE data Test dengan 80 fitur dan 150 trees:0.95
# Recall model RFE data Train dengan 80 fitur dan 150 trees:1.0
# Recall model RFE data Test dengan 80 fitur dan 150 trees:0.95
#
# CPU times: user 2.12 s, sys: 20.2 ms, total: 2.14 s
# Wall time: 2.14 s

# %%
# %%time
#tentukan metode scoring yang digunakan
scoring_rfe = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur dan trees yang digunakan dalam proses klasifikasi ini
#n_feat = [10, 20, 30]
n_feat = [80]
n_trees = [200]

for nfeat in n_feat:
    for ntrees in n_trees:        
        #ambil n fitur input hasil seleksi fitur Forward 
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Gaussian Classifier
        clf_rfe = RandomForestClassifier(n_estimators=ntrees)
        
        #Train the model using the training sets
        clf_rfe.fit(x_train_selected, y_train)
        y_pred_rfe=clf_rfe.predict(x_test_selected)
        
        #hitung score model dari data train
        scores_rfe = cross_validate(clf_rfe, x_train_selected, y_train, scoring=scoring_rfe, cv=cv, return_train_score=True)
        
        print("Akurasi model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_acc'].mean(), 2)))
        print("Akurasi model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.accuracy_score(y_test, y_pred_rfe), 2)))
        print("Precision model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_prec_micro'].mean(), 2)))
        print("Precision model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.precision_score(y_test, y_pred_rfe, average='micro'), 2)))
        print("Recall model RFE data Train dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(scores_rfe['train_rec_micro'].mean(), 2)))
        print("Recall model RFE data Test dengan " + str(nfeat) + " fitur dan " + str(ntrees) + " trees:" 
              + str(round(metrics.recall_score(y_test, y_pred_rfe, average='micro'), 2)))
        print(" ")
# Out:
# Akurasi model RFE data Train dengan 80 fitur dan 200 trees:1.0
# Akurasi model RFE data Test dengan 80 fitur dan 200 trees:0.95
# Precision model RFE data Train dengan 80 fitur dan 200 trees:1.0
# Precision model RFE data Test dengan 80 fitur dan 200 trees:0.95
# Recall model RFE data Train dengan 80 fitur dan 200 trees:1.0
# Recall model RFE data Test dengan 80 fitur dan 200 trees:0.95
#
# CPU times: user 2.73 s, sys: 8.24 ms, total: 2.74 s
# Wall time: 2.74 s

# %% [markdown]
# # Klasifikasi Support Vector Machine

# %% [markdown]
# Untuk train dan test set, serta cv-nya ambil dari yang Random Forest Classifier, sama aja

# %% [markdown]
# ## Testing Performa Model Support Vector Machine

# %%
# %%time
#tentukan metode scoring yang digunakan
scoring_svm = {'acc': 'accuracy',
               'prec_micro': 'precision_micro',
               'rec_micro': 'recall_micro'}

#tentukan total fitur yang digunakan dalam proses klasifikasi SVM ini
#n_feat = [10, 20, 30]
n_feat = [80]

for nfeat in n_feat:     
    #ambil n fitur input hasil seleksi fitur Forward 
    x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
    x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

    #Create a Support Vector Classifier
    clf_svm = svm.SVC()

    #Train the model using the training sets
    clf_svm.fit(x_train_selected, y_train)
    y_pred_svm = clf_svm.predict(x_test_selected)

    #hitung score model dari data train
    scores_svm = cross_validate(clf_svm, x_train_selected, y_train, scoring=scoring_svm, cv=cv, return_train_score=True)

    print("akurasi model SVM data Train dengan " + str(nfeat) + " fitur: " 
          + str(round(scores_svm['train_acc'].mean(), 2)))
    print("akurasi model SVM data Test dengan " + str(nfeat) + " fitur: " 
          + str(round(metrics.accuracy_score(y_test, y_pred_svm), 2)))
    print("Precision model SVM data Train dengan " + str(nfeat) + " fitur:"
          + str(round(scores_svm['train_prec_micro'].mean(), 2)))
    print("Precision model SVM data Test dengan " + str(nfeat) + " fitur:"
          + str(round(metrics.precision_score(y_test, y_pred_svm, average='micro'), 2)))
    print("Recall model SVM data Train dengan " + str(nfeat) + " fitur:"
          + str(round(scores_svm['train_rec_micro'].mean(), 2)))
    print("Recall model SVM data Test dengan " + str(nfeat) + " fitur:"
          + str(round(metrics.recall_score(y_test, y_pred_svm, average='micro'), 2)))
    print(" ")
# Out:
# akurasi model SVM data Train dengan 80 fitur: 0.75
# akurasi model SVM data Test dengan 80 fitur: 0.66
# Precision model SVM data Train dengan 80 fitur:0.75
# Precision model SVM data Test dengan 80 fitur:0.66
# Recall model SVM data Train dengan 80 fitur:0.75
# Recall model SVM data Test dengan 80 fitur:0.66
#
# CPU times: user 119 ms, sys: 57 µs, total: 119 ms
# Wall time: 116 ms
